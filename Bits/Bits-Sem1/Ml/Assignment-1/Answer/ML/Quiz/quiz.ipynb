# %% [markdown]
# Here is the complete list of all questions with their correct answers based on the reasoning provided earlier.
#
# ---
#
# **Question 1**
# A key advantage of Mini-Batch GD over pure SGD is:
# A. It always converges to the global minimum
# B. It removes the need for learning rate scheduling
# C. It eliminates hyperparameter tuning
# D. It leverages vectorized operations for computational efficiency
#
# **Answer: D**
#
# ---
#
# **Question 2**
# An overparameterized deep neural network achieves zero training error but shows a high generalization error on the test set. In the context of the Bias-Variance decomposition, which of the following statements best describes the state of the model?
# A. Both intrinsic bias and variance are minimized because the model's capacity is large enough to handle the true data-generating function.
# B. The model has low bias and high variance, meaning it has captured the underlying noise in the training data alongside the true distribution.
# C. The model's irreducible error has increased due to the high complexity of the architecture.
# D. The model has high bias and low variance because it perfectly fits the complex decision boundaries of the training data.
#
# **Answer: B**
#
# ---
#
# **Question 3**
# Consider a Mean Squared Error (MSE) cost function for a standard linear regression model. Why is MSE preferred over Mean Absolute Error (MAE) when optimization is performed using standard gradient descent architectures?
# A. MSE is less sensitive to outliers than MAE, which ensures steadier gradient updates during early epochs.
# B. MSE is globally convex whereas MAE is non-convex, leading to multiple local minima during optimization.
# C. The gradient of MSE decreases dynamically as the parameters approach the global minimum, allowing for natural convergence without drastically changing the learning rate.
# D. MAE produces a constant gradient everywhere, which causes gradient descent to always diverge away from the optimal point.
#
# **Answer: C**
#
# ---
#
# **Question 4**
# Logistic regression can’t be kernelised. True or False?
# **Answer: False**
#
# ---
#
# **Question 5**
# Which of the following correctly expresses the decomposition of expected prediction error?
# A. Error = Bias² × Variance
# B. Error = Bias² + Variance + Irreducible Noise
# C. Error = Bias + Variance² + Noise
# D. Error = Bias + Variance
#
# **Answer: B**
#
# ---
#
# **Question 6**
# Suppose you are optimizing a model where the feature vectors have massive scale disparities (e.g., Feature 1 ranges from 0 to 1, while Feature 2 ranges from -1,000,000 to 1,000,000). How does this disparity affect the cost function contours and subsequent Gradient Descent convergence?
# A. The cost function becomes highly asymmetrical and elongated, requiring an extremely small learning rate to avoid divergence in the steep feature dimension.
# B. The contours become perfectly spherical, ensuring rapid convergence in a few iterations.
# C. Gradient descent becomes entirely invariant to feature scaling, so convergence speed is unaffected.
# D. The cost function loses its convexity completely, introducing multiple local minima along the larger feature axis.
#
# **Answer: A**
#
# ---
#
# **Question 7**
# Which of the following methods do we use to find the best fit line for data in Linear Regression?
# A. Logarithmic Loss
# B. Both Least Square error and maximum likelihood
# C. Least Square Error
# D. Maximum Likelihood
#
# **Answer: B**
#
# ---
#
# **Question 8**
# Stochastic Gradient Descent (SGD) differs from Batch GD in that:
# A. SGD uses the entire dataset per update
# B. SGD does not require a learning rate
# C. SGD updates parameters using one training example at a time
# D. SGD computes the exact gradient every iteration
#
# **Answer: C**
#
# ---
#
# **Question 9**
# In structural risk minimization, how does the addition of an explicit complexity penalty term to the empirical risk cost function modify the goal of the optimization process?
# A. It removes the irreducible error from the total expected risk formulation.
# B. It shifts the target from minimizing only the training error (minimizing bias) to minimizing an upper bound on the generalization error (balancing bias and variance).
# C. It forces the optimization path to strictly seek out points where the variance component of the error is exactly zero.
# D. It guarantees that the training error will reach absolute zero faster than unregularized optimization.
#
# **Answer: B**
#
# ---
#
# **Question 10**
# What methods can be used to address overfitting?
# A. Neither reducing the number of features nor regularisation.
# B. Only regularisation
# C. Only reducing the number of features
# D. Reducing the number of features and regularization
#
# **Answer: D**
#
# ---
#
# **Question 11**
# When a trained logistic regression classifier gives a prediction for a new example 'x', it means:
# A. Our estimate for P(y=0 | x)
# B. Our estimate for P(y=1 | x)
# C. Our estimate for P(y=0.2 | x)
# D. Our estimate for P(y=2 | x)
#
# **Answer: B**
#
# ---
#
# **Question 12**
# Choose the appropriate statement for logistic regression:
# A. If P(Y=1|X, θ) = 0 and actual class label is 1 then cross entropy cost will be very high for logistic regression
# B. If P(Y=1|X, θ) = 1 and actual class label is 1 then cross entropy cost will be very high for logistic regression
# C. If P(Y=0|X, θ) = 0 and actual class label is 1 then cross entropy cost will be very high for logistic regression
# D. If P(Y=1|X, θ) = 0 and actual class label is 0 then cross entropy cost will be very high for logistic regression
#
# **Answer: A**
#
# ---
#
# **Question 13**
# A model suffering from underfitting will be having:
# A. High Variance
# B. None of the options
# C. Both bias and variance
# D. High Bias
#
# **Answer: D**
#
# ---
#
# **Question 14**
# What is the minimum and maximum number of parameters we need if we wish to fit a quadratic curve to data?
# A. None of the options
# B. 0 and 3
# C. 2 and 3
# D. 1 and 3
#
# **Answer: D**
#
# ---
#
# **Question 15**
# A model suffering from overfitting will be having:
# A. None of the options
# B. High Bias
# C. Both bias and variance
# D. High Variance
#
# **Answer: D**
#
# ---
#
# **Question 16**
# During the training of a logistic regression model using Batch Gradient Descent, you observe that the cost function oscillates wildly and the parameter values grow exponentially. What is the most likely structural issue, and how should it be resolved?
# A. The cost function is non-convex; you should switch to Stochastic Gradient Descent to find a better initialization point.
# B. The features have not been normalized, which changes the convexity of the cost function into a non-convex space.
# C. The learning rate alpha exceeds the analytical upper bound determined by the Lipschitz constant of the gradient; you must decrease alpha.
# D. The learning rate alpha is too small; it should be increased to skip over local maxima.
#
# **Answer: C**
#
# ---
#
# **Question 17**
# Which of the following belong to the class of Sigmoid Functions?
# A. sin(x)
# B. |x|
# C. cos(x)
# D. σ(x) = 1/(1 + e^(−x))
#
# **Answer: D**
#
# ---
#
# **Question 18**
# A linear regression model always outputs values between 0 and 1. True or False?
# **Answer: False**
#
# ---
#
# **Question 19**
# Choose the appropriate option which indicates the correct properties of a sigmoid function:
# A. Sigmoid function is used for multiclass classification problem
# B. It acts as a squashing function because it maps the whole real axis into a finite interval
# C. Sigmoid function is a linear function
# D. Derivative of a sigmoid function is computationally complex statement for logistic regression.
#
# **Answer: B**
#
# ---
#
# **Question 20**
# Which of the following is a good test dataset characteristic?
# A. It should come from same distribution as training set
# B. larger than training set
# C. None of the given choices
# D. All the given choices
#
# **Answer: A**
#
# ---
#
# Let me know if you'd like this as a separate file or formatted differently.
