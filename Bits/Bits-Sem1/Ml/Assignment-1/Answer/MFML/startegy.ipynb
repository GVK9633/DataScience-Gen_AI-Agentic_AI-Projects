# %% [markdown]
# Preparation Strategy
# For MFML Midsem, focus heavily on:
# Gaussian Elimination
# Matrix Rank
# Linear Independence
# Eigenvalues & Eigenvectors
# Vector Spaces
# Orthogonality
# Basic Optimization
