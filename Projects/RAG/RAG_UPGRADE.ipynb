# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#!pip install -r requirement.txt
# Out:
# Collecting chromadb==0.5.5 (from -r requirement.txt (line 1))
#   Downloading chromadb-0.5.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-chroma==0.1.2 (from -r requirement.txt (line 2))
#   Downloading langchain_chroma-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting langchain==0.2.11 (from -r requirement.txt (line 3))
#   Downloading langchain-0.2.11-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-community==0.2.10 (from -r requirement.txt (line 4))
#   Downloading langchain_community-0.2.10-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain-text-splitters==0.2.2 (from -r requirement.txt (line 5))
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-groq==0.1.6 (from -r requirement.txt (line 6))
#   Downloading langchain_groq-0.1.6-py3-none-any.whl.metadata (2.8 kB)
# Collecting transformers==4.43.2 (from -r requirement.txt (line 7))
#   Downloading transformers-4.43.2-py3-none-any.whl.metadata (43 kB)
# Collecting sentence-transformers==3.0.1 (from -r requirement.txt (line 8))
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting unstructured==0.15.0 (from -r requirement.txt (line 9))
#   Downloading unstructured-0.15.0-py3-none-any.whl.metadata (29 kB)
# Collecting build>=1.0.3 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (2.11.5)
# Collecting chroma-hnswlib==0.7.6 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (252 bytes)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (0.115.14)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.5->-r requirement.txt (line 1)) (0.35.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading posthog-6.7.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (4.14.1)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading onnxruntime-1.22.1-cp310-cp310-macosx_13_0_universal2.whl.metadata (4.6 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (1.34.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_instrumentation_fastapi-0.57b0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (0.21.4)
# Collecting pypika>=0.48.9 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (7.7.0)
# Collecting importlib-resources (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (1.73.1)
# Collecting bcrypt>=4.0.1 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (0.16.0)
# Collecting kubernetes>=28.1.0 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading mmh3-5.2.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb==0.5.5->-r requirement.txt (line 1)) (0.28.1)
# Collecting langchain-core<0.3,>=0.1.40 (from langchain-chroma==0.1.2->-r requirement.txt (line 2))
#   Downloading langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain==0.2.11->-r requirement.txt (line 3)) (2.0.41)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain==0.2.11->-r requirement.txt (line 3)) (3.12.15)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain==0.2.11->-r requirement.txt (line 3)) (4.0.3)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.11->-r requirement.txt (line 3))
#   Downloading langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests<3,>=2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain==0.2.11->-r requirement.txt (line 3)) (2.32.4)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.2.10->-r requirement.txt (line 4))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: groq<1,>=0.4.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-groq==0.1.6->-r requirement.txt (line 6)) (0.31.0)
# Requirement already satisfied: filelock in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.43.2->-r requirement.txt (line 7)) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.43.2->-r requirement.txt (line 7)) (0.34.3)
# Requirement already satisfied: packaging>=20.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.43.2->-r requirement.txt (line 7)) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.43.2->-r requirement.txt (line 7)) (2025.7.34)
# Collecting tokenizers>=0.13.2 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Using cached tokenizers-0.19.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.43.2->-r requirement.txt (line 7)) (0.5.3)
# Requirement already satisfied: torch>=1.11.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirement.txt (line 8)) (2.7.1)
# Requirement already satisfied: scikit-learn in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirement.txt (line 8)) (1.3.2)
# Requirement already satisfied: scipy in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirement.txt (line 8)) (1.15.3)
# Requirement already satisfied: Pillow in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirement.txt (line 8)) (10.0.1)
# Collecting chardet (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: filetype in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured==0.15.0->-r requirement.txt (line 9)) (1.2.0)
# Collecting python-magic (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured==0.15.0->-r requirement.txt (line 9)) (5.4.0)
# Collecting nltk (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting tabulate (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured==0.15.0->-r requirement.txt (line 9)) (4.13.4)
# Collecting emoji (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting python-iso639 (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 5.2 MB/s  0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading rapidfuzz-3.14.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting backoff (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured==0.15.0->-r requirement.txt (line 9))
#   Downloading unstructured_client-0.42.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured==0.15.0->-r requirement.txt (line 9)) (1.17.2)
# Requirement already satisfied: psutil in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured==0.15.0->-r requirement.txt (line 9)) (7.0.0)
# Collecting onnx (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading onnx-1.19.0-cp310-cp310-macosx_12_0_universal2.whl.metadata (7.0 kB)
# Collecting pdf2image (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pdfminer.six (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Collecting pikepdf (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pikepdf-9.10.2-cp310-cp310-macosx_14_0_arm64.whl.metadata (8.1 kB)
# Collecting pillow-heif (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pillow_heif-1.1.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (9.6 kB)
# Collecting pypdf (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pypdf-6.0.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pytesseract in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (0.3.13)
# Collecting google-cloud-vision (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading google_cloud_vision-3.10.2-py3-none-any.whl.metadata (9.6 kB)
# Collecting effdet (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting unstructured-inference==0.7.36 (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading unstructured_inference-0.7.36-py3-none-any.whl.metadata (5.9 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Collecting layoutparser (from unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: python-multipart in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (0.0.20)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (4.11.0.86)
# Requirement already satisfied: matplotlib in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (3.10.3)
# Collecting timm (from unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading timm-1.0.19-py3-none-any.whl.metadata (60 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11->-r requirement.txt (line 3)) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10->-r requirement.txt (line 4))
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10->-r requirement.txt (line 4))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb==0.5.5->-r requirement.txt (line 1)) (0.46.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.6->-r requirement.txt (line 6)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.6->-r requirement.txt (line 6)) (1.9.0)
# Requirement already satisfied: sniffio in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.6->-r requirement.txt (line 6)) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.1.6->-r requirement.txt (line 6)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.1.6->-r requirement.txt (line 6)) (3.10)
# Requirement already satisfied: certifi in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb==0.5.5->-r requirement.txt (line 1)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb==0.5.5->-r requirement.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.5->-r requirement.txt (line 1)) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.43.2->-r requirement.txt (line 7)) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.43.2->-r requirement.txt (line 7)) (1.1.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma==0.1.2->-r requirement.txt (line 2)) (1.33)
# Collecting packaging>=20.0 (from transformers==4.43.2->-r requirement.txt (line 7))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.40->langchain-chroma==0.1.2->-r requirement.txt (line 2)) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11->-r requirement.txt (line 3)) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic>=1.9->chromadb==0.5.5->-r requirement.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic>=1.9->chromadb==0.5.5->-r requirement.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic>=1.9->chromadb==0.5.5->-r requirement.txt (line 1)) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.2.11->-r requirement.txt (line 3)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.2.11->-r requirement.txt (line 3)) (2.5.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10->-r requirement.txt (line 4))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from build>=1.0.3->chromadb==0.5.5->-r requirement.txt (line 1)) (2.2.1)
# Requirement already satisfied: six>=1.9.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (3.3.1)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.5->-r requirement.txt (line 1)) (0.6.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1)) (25.2.10)
# Requirement already satisfied: protobuf in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1)) (4.25.3)
# Requirement already satisfied: sympy in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.5->-r requirement.txt (line 1)) (6.11.0)
# Requirement already satisfied: zipp>=0.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.5->-r requirement.txt (line 1)) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.5->-r requirement.txt (line 1)) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading protobuf-6.32.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk>=1.2.0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-asgi==0.57b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_instrumentation_asgi-0.57b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.57b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_instrumentation-0.57b0-py3-none-any.whl.metadata (6.7 kB)
# Collecting opentelemetry-util-http==0.57b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading opentelemetry_util_http-0.57b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.57b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading asgiref-3.9.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: networkx in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirement.txt (line 8)) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirement.txt (line 8)) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer>=0.9.0->chromadb==0.5.5->-r requirement.txt (line 1)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer>=0.9.0->chromadb==0.5.5->-r requirement.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer>=0.9.0->chromadb==0.5.5->-r requirement.txt (line 1)) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.5->-r requirement.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.5->-r requirement.txt (line 1)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.5->-r requirement.txt (line 1)) (0.1.2)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading httptools-0.6.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.5->-r requirement.txt (line 1)) (1.1.0)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading uvloop-0.21.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading watchfiles-1.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.5->-r requirement.txt (line 1)) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from beautifulsoup4->unstructured==0.15.0->-r requirement.txt (line 9)) (2.7)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.5->-r requirement.txt (line 1))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: torchvision in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from effdet->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (0.22.1)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pycocotools-2.0.10-cp310-cp310-macosx_10_9_universal2.whl.metadata (1.3 kB)
# Collecting omegaconf>=2.0 (from effdet->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (2.25.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-cloud-vision->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (1.26.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (1.62.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1->-r requirement.txt (line 8)) (3.0.2)
# Requirement already satisfied: pandas in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (2.3.0)
# Collecting iopath (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Collecting portalocker (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (3.2.3)
# Requirement already satisfied: joblib in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk->unstructured==0.15.0->-r requirement.txt (line 9)) (1.5.1)
# Requirement already satisfied: ml_dtypes in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnx->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (0.5.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (2025.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pdfminer.six->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (45.0.5)
# Requirement already satisfied: cffi>=1.14 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (1.17.1)
# Requirement already satisfied: pycparser in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]==0.15.0->-r requirement.txt (line 10)) (2.22)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
# Collecting Deprecated (from pikepdf->unstructured[pdf]==0.15.0->-r requirement.txt (line 10))
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting Pillow (from sentence-transformers==3.0.1->-r requirement.txt (line 8))
#   Downloading pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from scikit-learn->sentence-transformers==3.0.1->-r requirement.txt (line 8)) (3.6.0)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-client->unstructured==0.15.0->-r requirement.txt (line 9)) (24.1.0)
# Downloading chromadb-0.5.5-py3-none-any.whl (584 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 4.8 MB/s  0:00:00
# Downloading langchain_chroma-0.1.2-py3-none-any.whl (9.3 kB)
# Downloading langchain-0.2.11-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 6.2 MB/s  0:00:00
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langchain_community-0.2.10-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.7 MB/s  0:00:00 eta 0:00:01
# Downloading langchain_groq-0.1.6-py3-none-any.whl (14 kB)
# Downloading transformers-4.43.2-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 6.3 MB/s  0:00:01 eta 0:00:01
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Downloading unstructured-0.15.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.9 MB/s  0:00:00 eta 0:00:01
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-macosx_11_0_arm64.whl (183 kB)
# Downloading unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached tokenizers-0.19.1-cp310-cp310-macosx_11_0_arm64.whl (2.4 MB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl (498 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.6 MB/s  0:00:00 eta 0:00:01
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp310-cp310-macosx_11_0_arm64.whl (40 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading onnxruntime-1.22.1-cp310-cp310-macosx_13_0_universal2.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 6.0 MB/s  0:00:05m0:00:0100:01
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading protobuf-6.32.0-cp39-abi3-macosx_10_9_universal2.whl (426 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.57b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.57b0-py3-none-any.whl (32 kB)
# Downloading opentelemetry_instrumentation_asgi-0.57b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.57b0-py3-none-any.whl (7.6 kB)
# Downloading asgiref-3.9.1-py3-none-any.whl (23 kB)
# Downloading posthog-6.7.1-py3-none-any.whl (124 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading httptools-0.6.4-cp310-cp310-macosx_11_0_arm64.whl (103 kB)
# Downloading uvloop-0.21.0-cp310-cp310-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.9 MB/s  0:00:00 eta 0:00:01
# Downloading watchfiles-1.1.0-cp310-cp310-macosx_11_0_arm64.whl (397 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading pycocotools-2.0.10-cp310-cp310-macosx_10_9_universal2.whl (152 kB)
# Downloading timm-1.0.19-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 4.4 MB/s  0:00:00 eta 0:00:01
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 4.3 MB/s  0:00:00
# Downloading google_cloud_vision-3.10.2-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.9/527.9 kB 4.3 MB/s  0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 5.1 MB/s  0:00:03m0:00:0100:01
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading onnx-1.19.0-cp310-cp310-macosx_12_0_universal2.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 5.0 MB/s  0:00:03 eta 0:00:01
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 4.9 MB/s  0:00:01 eta 0:00:01
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Downloading pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 5.4 MB/s  0:00:00 eta 0:00:01
# Downloading pikepdf-9.10.2-cp310-cp310-macosx_14_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.7 MB/s  0:00:01 eta 0:00:01
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading pillow_heif-1.1.0-cp310-cp310-macosx_14_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 1.0 MB/s  0:00:020m eta 0:00:01
# Downloading pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.9 MB/s  0:00:01 eta 0:00:01
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading pypdf-6.0.0-py3-none-any.whl (310 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading rapidfuzz-3.14.0-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.9 MB/s  0:00:00 eta 0:00:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading unstructured_client-0.42.3-py3-none-any.whl (207 kB)
# Building wheels for collected packages: pypika, antlr4-python3-runtime, langdetect, iopath
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=35adc6c928dbef0add6f76f0be2bcb2b8cd2b1a4931feaad30ad684d356e5e60
#   Stored in directory: /Users/gvijaykumarachary/Library/Caches/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
#   DEPRECATION: Building 'antlr4-python3-runtime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'antlr4-python3-runtime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=8d6a7276547536707929c2a541b9b39c6b45af1d5915d1c32ca411508b5a6f02
#   Stored in directory: /Users/gvijaykumarachary/Library/Caches/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=7cd4fbe730409294b9270787a22def797c65067e69095fbcb6785f79645df24e
#   Stored in directory: /Users/gvijaykumarachary/Library/Caches/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   DEPRECATION: Building 'iopath' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'iopath'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=64646d64a2195a7b54e7fbc21366409ad9ece69d05f6b85831cc1108423cc3f8
#   Stored in directory: /Users/gvijaykumarachary/Library/Caches/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built pypika antlr4-python3-runtime langdetect iopath
# Installing collected packages: pypika, durationpy, antlr4-python3-runtime, uvloop, tabulate, rapidfuzz, python-magic, python-iso639, pyproject_hooks, pypdfium2, pypdf, pycocotools, protobuf, portalocker, Pillow, packaging, opentelemetry-util-http, omegaconf, nltk, mypy-extensions, mmh3, langdetect, importlib-resources, humanfriendly, httptools, emoji, Deprecated, chroma-hnswlib, chardet, bcrypt, backoff, asgiref, unstructured.pytesseract, typing-inspect, posthog, pillow-heif, pikepdf, pdf2image, opentelemetry-proto, opentelemetry-api, onnx, marshmallow, iopath, coloredlogs, build, watchfiles, tokenizers, pdfminer.six, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, dataclasses-json, unstructured-client, transformers, timm, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, langsmith, unstructured, sentence-transformers, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, layoutparser, langchain-core, google-cloud-vision, effdet, unstructured-inference, opentelemetry-instrumentation-fastapi, langchain-text-splitters, langchain-groq, langchain, chromadb, langchain-community, langchain-chroma
#   Attempting uninstall: protobuf━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/76 [python-iso639]
#     Found existing installation: protobuf 4.25.3━━━━━━━━━━━━━━  7/76 [python-iso639]
#     Uninstalling protobuf-4.25.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/76 [python-iso639]
#       Successfully uninstalled protobuf-4.25.3━━━━━━━━━━━━━━━━  7/76 [python-iso639]
#   Attempting uninstall: Pillow90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/76 [protobuf]]
#     Found existing installation: Pillow 10.0.1━━━━━━━━━━━━━━━━ 12/76 [protobuf]
#     Uninstalling Pillow-10.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/76 [protobuf]
#       Successfully uninstalled Pillow-10.0.1━━━━━━━━━━━━━━━━━━ 12/76 [protobuf]
#   Attempting uninstall: packagingm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/76 [Pillow]
#     Found existing installation: packaging 25.0━━━━━━━━━━━━━━━ 14/76 [Pillow]
#     Uninstalling packaging-25.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/76 [Pillow]
#       Successfully uninstalled packaging-25.0━━━━━━━━━━━━━━━━━ 14/76 [Pillow]
#   Attempting uninstall: opentelemetry-api90m━━━━━━━━━━━━━━━━━━━━━━ 33/76 [typing-inspect]
#     Found existing installation: opentelemetry-api 1.34.1━━━━━ 33/76 [typing-inspect]
#     Uninstalling opentelemetry-api-1.34.1:━━━━━━━━━━━━━━━━━━━━ 33/76 [typing-inspect]
#       Successfully uninstalled opentelemetry-api-1.34.1━━━━━━━ 33/76 [typing-inspect]
#   Attempting uninstall: tokenizers╺━━━━━━━━━━━━━━━━━━ 40/76 [onnx]spect]
#     Found existing installation: tokenizers 0.21.4━━━━━━━━━━━━ 40/76 [onnx]
#     Uninstalling tokenizers-0.21.4:━━━━━━━━━━━━━━━━━━ 40/76 [onnx]
#       Successfully uninstalled tokenizers-0.21.4━━━━━━━━━━━━━━ 40/76 [onnx]
#   Attempting uninstall: opentelemetry-semantic-conventions━━━━━━━━ 47/76 [pdfminer.six]
#     Found existing installation: opentelemetry-semantic-conventions 0.55b1/76 [pdfminer.six]
#     Uninstalling opentelemetry-semantic-conventions-0.55b1:━━━ 47/76 [pdfminer.six]
#       Successfully uninstalled opentelemetry-semantic-conventions-0.55b147/76 [pdfminer.six]
#   Attempting uninstall: transformers╸━━━━━━━━━━━━ 53/76 [unstructured-client]
#     Found existing installation: transformers 4.55.0━━━━━━━━━━ 53/76 [unstructured-client]
#     Uninstalling transformers-4.55.0:╺━━━━━━━━━━━ 54/76 [transformers]nt]
#       Successfully uninstalled transformers-4.55.0m━━━━━━━━━━━ 54/76 [transformers]
#   Attempting uninstall: opentelemetry-sdk╸━━━━━━━━━━━ 55/76 [timm]formers]
#     Found existing installation: opentelemetry-sdk 1.34.1━━━━━ 55/76 [timm]
#     Uninstalling opentelemetry-sdk-1.34.1:━━━━━━━━━━━ 55/76 [timm]
#       Successfully uninstalled opentelemetry-sdk-1.34.1━━━━━━━ 55/76 [timm]
#   Attempting uninstall: langsmith━━━━╸━━━━━━━━━ 58/76 [opentelemetry-instrumentation]
#     Found existing installation: langsmith 0.3.4590m━━━━━━━━━ 58/76 [opentelemetry-instrumentation]
#     Uninstalling langsmith-0.3.45:╸━━━━━━━━━ 58/76 [opentelemetry-instrumentation]
#       Successfully uninstalled langsmith-0.3.45━━━━━━━━━ 58/76 [opentelemetry-instrumentation]
#   Attempting uninstall: langchain-core━━━╸━━━━━━ 64/76 [layoutparser]rumentation]
#     Found existing installation: langchain-core 0.3.700m━━━━━━ 64/76 [layoutparser]
#     Uninstalling langchain-core-0.3.70:0m╸━━━━━━ 64/76 [layoutparser]
#       Successfully uninstalled langchain-core-0.3.70━━━━━━ 64/76 [layoutparser]
#   Attempting uninstall: langchain-text-splitters91m╸━━━━━ 66/76 [google-cloud-vision]
#     Found existing installation: langchain-text-splitters 0.3.8 66/76 [google-cloud-vision]
#     Uninstalling langchain-text-splitters-0.3.8:━━━━━ 66/76 [google-cloud-vision]
#       Successfully uninstalled langchain-text-splitters-0.3.8━ 66/76 [google-cloud-vision]
#   Attempting uninstall: langchain━━━━━╸━━━━━ 66/76 [google-cloud-vision]
#     Found existing installation: langchain 0.3.26╸━━ 72/76 [langchain]ision]
#     Uninstalling langchain-0.3.26:━━━━━━━╸━━ 72/76 [langchain]
#       Successfully uninstalled langchain-0.3.260m╸━━ 72/76 [langchain]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76/76 [langchain-chroma][langchain-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.32.0 which is incompatible.
# langchain-google-genai 2.1.8 requires google-ai-generativelanguage<0.7.0,>=0.6.18, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# langchain-google-genai 2.1.8 requires langchain-core<0.4.0,>=0.3.68, but you have langchain-core 0.2.43 which is incompatible.
# langchain-openai 0.3.28 requires langchain-core<1.0.0,>=0.3.68, but you have langchain-core 0.2.43 which is incompatible.
# langgraph-prebuilt 0.2.2 requires langchain-core>=0.3.22, but you have langchain-core 0.2.43 which is incompatible.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 6.32.0 which is incompatible.
# streamlit 1.28.1 requires packaging<24,>=16.8, but you have packaging 24.2 which is incompatible.
# streamlit 1.28.1 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# streamlit 1.28.1 requires protobuf<5,>=3.20, but you have protobuf 6.32.0 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.0 which is incompatible.
# Successfully installed Deprecated-1.2.18 Pillow-11.3.0 antlr4-python3-runtime-4.9.3 asgiref-3.9.1 backoff-2.2.1 bcrypt-4.3.0 build-1.3.0 chardet-5.2.0 chroma-hnswlib-0.7.6 chromadb-0.5.5 coloredlogs-15.0.1 dataclasses-json-0.6.7 durationpy-0.10 effdet-0.4.1 emoji-2.14.1 google-cloud-vision-3.10.2 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 iopath-0.1.10 kubernetes-33.1.0 langchain-0.2.11 langchain-chroma-0.1.2 langchain-community-0.2.10 langchain-core-0.2.43 langchain-groq-0.1.6 langchain-text-splitters-0.2.2 langdetect-1.0.9 langsmith-0.1.147 layoutparser-0.3.4 marshmallow-3.26.1 mmh3-5.2.0 mypy-extensions-1.1.0 nltk-3.9.1 omegaconf-2.3.0 onnx-1.19.0 onnxruntime-1.22.1 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-grpc-1.36.0 opentelemetry-instrumentation-0.57b0 opentelemetry-instrumentation-asgi-0.57b0 opentelemetry-instrumentation-fastapi-0.57b0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 opentelemetry-util-http-0.57b0 packaging-24.2 pdf2image-1.17.0 pdfminer.six-20250506 pdfplumber-0.11.7 pikepdf-9.10.2 pillow-heif-1.1.0 portalocker-3.2.0 posthog-6.7.1 protobuf-6.32.0 pycocotools-2.0.10 pypdf-6.0.0 pypdfium2-4.30.0 pypika-0.48.9 pyproject_hooks-1.2.0 python-iso639-2025.2.18 python-magic-0.4.27 rapidfuzz-3.14.0 sentence-transformers-3.0.1 tabulate-0.9.0 timm-1.0.19 tokenizers-0.19.1 transformers-4.43.2 typing-inspect-0.9.0 unstructured-0.15.0 unstructured-client-0.42.3 unstructured-inference-0.7.36 unstructured.pytesseract-0.3.15 uvloop-0.21.0 watchfiles-1.1.0

# %%
# !pip install -U chromadb langchain-groq langchain-community langchain-chroma langchain-text-splitters transformers sentence-transformers unstructured "unstructured[pdf]"
# Out:
# Requirement already satisfied: chromadb in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.5.5)
# Collecting chromadb
#   Downloading chromadb-1.0.20-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: langchain-groq in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.1.6)
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.7-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-community in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.2.10)
# Collecting langchain-community
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-chroma in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.1.2)
# Collecting langchain-chroma
#   Downloading langchain_chroma-0.2.5-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: langchain-text-splitters in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.2.2)
# Collecting langchain-text-splitters
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: transformers in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (4.43.2)
# Collecting transformers
#   Downloading transformers-4.56.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: sentence-transformers in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (3.0.1)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: unstructured in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.15.0)
# Collecting unstructured
#   Downloading unstructured-0.18.14-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: build>=1.0.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (2.11.5)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.26.4)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.4)
# Requirement already satisfied: six>=1.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.8.3)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain-groq)
#   Downloading langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: groq<1,>=0.30.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-groq) (0.31.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from groq<1,>=0.30.0->langchain-groq) (4.9.0)
# Requirement already satisfied: sniffio in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Collecting langsmith>=0.3.45 (from langchain-core<1.0.0,>=0.3.72->langchain-groq)
#   Downloading langsmith-0.4.21-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (1.33)
# Requirement already satisfied: packaging>=23.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Collecting langchain<2.0.0,>=0.3.27 (from langchain-community)
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-community) (2.0.41)
# Collecting requests<3.0,>=2.7 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: filelock in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (0.34.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (2025.7.34)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.22.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: torch>=1.11.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: Pillow in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: filetype in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (5.4.0)
# Requirement already satisfied: nltk in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (4.13.4)
# Requirement already satisfied: emoji in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: python-iso639 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (3.14.0)
# Requirement already satisfied: unstructured-client in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (0.42.3)
# Requirement already satisfied: wrapt in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: psutil in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured) (7.0.0)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: onnx>=1.17.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (1.19.0)
# Requirement already satisfied: pdf2image in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer.six in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (20250506)
# Requirement already satisfied: pikepdf in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (9.10.2)
# Collecting pi-heif (from unstructured[pdf])
#   Downloading pi_heif-1.1.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: pypdf in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (6.0.0)
# Requirement already satisfied: google-cloud-vision in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (3.10.2)
# Requirement already satisfied: effdet in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (0.4.1)
# Collecting unstructured-inference>=1.0.5 (from unstructured[pdf])
#   Downloading unstructured_inference-1.0.5-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured[pdf]) (0.3.15)
# Requirement already satisfied: pyproject_hooks in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (0.23.0)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnx>=1.17.0->unstructured[pdf]) (6.32.0)
# Requirement already satisfied: ml_dtypes in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnx>=1.17.0->unstructured[pdf]) (0.5.1)
# Requirement already satisfied: coloredlogs in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.11.0)
# Requirement already satisfied: zipp>=0.5 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.57b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: python-multipart in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (0.0.20)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (4.11.0.86)
# Requirement already satisfied: matplotlib in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (3.10.3)
# Requirement already satisfied: timm in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (1.0.19)
# Requirement already satisfied: accelerate in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (1.9.0)
# Requirement already satisfied: pandas in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: pypdfium2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (4.30.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from beautifulsoup4->unstructured) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: torchvision in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from effdet->unstructured[pdf]) (0.22.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from effdet->unstructured[pdf]) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (4.9.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (2.25.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-cloud-vision->unstructured[pdf]) (1.26.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.62.3)
# Requirement already satisfied: webencodings in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (3.2.3)
# Requirement already satisfied: joblib in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk->unstructured) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->unstructured-inference>=1.0.5->unstructured[pdf]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pandas->unstructured-inference>=1.0.5->unstructured[pdf]) (2025.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pdfminer.six->unstructured[pdf]) (45.0.5)
# Requirement already satisfied: cffi>=1.14 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Requirement already satisfied: pycparser in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Requirement already satisfied: Deprecated in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from pikepdf->unstructured[pdf]) (1.2.18)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from unstructured-client->unstructured) (24.1.0)
# Downloading chromadb-1.0.20-cp39-abi3-macosx_11_0_arm64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 7.9 MB/s  0:00:02m0:00:0100:01
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading langchain_groq-0.3.7-py3-none-any.whl (16 kB)
# Downloading langchain_core-0.3.75-py3-none-any.whl (443 kB)
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.3 MB/s  0:00:00 eta 0:00:01
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.3 MB/s  0:00:00 eta 0:00:01
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading langchain_chroma-0.2.5-py3-none-any.whl (12 kB)
# Downloading transformers-4.56.0-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 4.4 MB/s  0:00:02 eta 0:00:01
# Downloading tokenizers-0.22.0-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 4.5 MB/s  0:00:00 eta 0:00:01
# Downloading sentence_transformers-5.1.0-py3-none-any.whl (483 kB)
# Downloading unstructured-0.18.14-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.2 MB/s  0:00:00 eta 0:00:01
# Downloading langsmith-0.4.21-py3-none-any.whl (378 kB)
# Downloading pybase64-1.4.2-cp310-cp310-macosx_11_0_arm64.whl (31 kB)
# Downloading unstructured_inference-1.0.5-py3-none-any.whl (48 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading pi_heif-1.1.0-cp310-cp310-macosx_14_0_arm64.whl (642 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.4/642.4 kB 3.5 MB/s  0:00:00
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Installing collected packages: requests, pybase64, pi-heif, olefile, html5lib, python-oxmsg, posthog, tokenizers, transformers, langsmith, unstructured-inference, unstructured, sentence-transformers, langchain-core, langchain-text-splitters, langchain-groq, chromadb, langchain-chroma, langchain, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: posthog
#     Found existing installation: posthog 6.7.1
#     Uninstalling posthog-6.7.1:
#       Successfully uninstalled posthog-6.7.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers━━━━━━━━━━━━━━━━━━━━━━━━━  7/20 [tokenizers]
#     Found existing installation: transformers 4.43.2━━━━━━━━━━  7/20 [tokenizers]
#     Uninstalling transformers-4.43.2:━━━━━━━━━━━━━━━━━━━━━━━━━  7/20 [tokenizers]
#       Successfully uninstalled transformers-4.43.2━━━━━━━━━━━━  7/20 [tokenizers]
#   Attempting uninstall: langsmith╺━━━━━━━━━━━━━━━━━━━━━━━  8/20 [transformers]
#     Found existing installation: langsmith 0.1.147━━━━━━━━━━━━  8/20 [transformers]
#     Uninstalling langsmith-0.1.147:━━━━━━━━━━━━━━━━━━━━━━━  8/20 [transformers]
#       Successfully uninstalled langsmith-0.1.147━━━━━━━━━━━━━━  8/20 [transformers]
#   Attempting uninstall: unstructured-inference━━━━━━━━━━━━━━━━━━━━  9/20 [langsmith]
#     Found existing installation: unstructured-inference 0.7.36  9/20 [langsmith]
#     Uninstalling unstructured-inference-0.7.36:━━━━━━━━━━━━━━━  9/20 [langsmith]
#       Successfully uninstalled unstructured-inference-0.7.36━━  9/20 [langsmith]
#   Attempting uninstall: unstructured━━━━━━━━━━━━━━━━━━━━━  9/20 [langsmith]
#     Found existing installation: unstructured 0.15.0━━━━━━━━━━  9/20 [langsmith]
#     Uninstalling unstructured-0.15.0:━━━━━━━━━━━━━━━━━━━━━  9/20 [langsmith]
#       Successfully uninstalled unstructured-0.15.0━━━━━━━━━━━━  9/20 [langsmith]
#   Attempting uninstall: sentence-transformers━━━━━━━━━━━━━━━━━ 11/20 [unstructured]
#     Found existing installation: sentence-transformers 3.0.1━━ 11/20 [unstructured]
#     Uninstalling sentence-transformers-3.0.1:━━━━━━━━━━━━━━━━━ 11/20 [unstructured]
#       Successfully uninstalled sentence-transformers-3.0.1━━━━ 11/20 [unstructured]
#   Attempting uninstall: langchain-core90m╺━━━━━━━━━━━━━━━ 12/20 [sentence-transformers]
#     Found existing installation: langchain-core 0.2.43━━━━━━━━ 12/20 [sentence-transformers]
#     Uninstalling langchain-core-0.2.43:━━━━━━━━━━━━━━━ 12/20 [sentence-transformers]
#       Successfully uninstalled langchain-core-0.2.43m━━━━━━━━━━━━━ 13/20 [langchain-core]rs]
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━ 13/20 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.2.2 13/20 [langchain-core]
#     Uninstalling langchain-text-splitters-0.2.2:m━━━━━━━━━━━━━ 13/20 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.2.2━ 13/20 [langchain-core]
#   Attempting uninstall: langchain-groqm╺━━━━━━━━━━━━━ 13/20 [langchain-core]
#     Found existing installation: langchain-groq 0.1.6━━━━━━━━━ 13/20 [langchain-core]
#     Uninstalling langchain-groq-0.1.6:m╺━━━━━━━━━━━━━ 13/20 [langchain-core]
#       Successfully uninstalled langchain-groq-0.1.6━━━━━━━━━━━ 13/20 [langchain-core]
#   Attempting uninstall: chromadb0m╺━━━━━━━━━━━━━ 13/20 [langchain-core]
#     Found existing installation: chromadb 0.5.50m━━━━━━━━━━━━━ 13/20 [langchain-core]
#     Uninstalling chromadb-0.5.5:0m╺━━━━━━━━━━━━━ 13/20 [langchain-core]
#       Successfully uninstalled chromadb-0.5.5━━━━━━━━━━━━━ 13/20 [langchain-core]
#   Attempting uninstall: langchain-chroma╺━━━━━━━ 16/20 [chromadb]e]
#     Found existing installation: langchain-chroma 0.1.2━━━━━━━ 16/20 [chromadb]
#     Uninstalling langchain-chroma-0.1.2:╺━━━━━━━ 16/20 [chromadb]
#       Successfully uninstalled langchain-chroma-0.1.20m━━━━━━━ 16/20 [chromadb]
#   Attempting uninstall: langchain━━━╺━━━━━━━ 16/20 [chromadb]
#     Found existing installation: langchain 0.2.11m━━━━━━━ 16/20 [chromadb]
#     Uninstalling langchain-0.2.11:━━━━━━━━━━╺━━━ 18/20 [langchain]
#       Successfully uninstalled langchain-0.2.11m╺━━━ 18/20 [langchain]
#   Attempting uninstall: langchain-community━╺━━━ 18/20 [langchain]
#     Found existing installation: langchain-community 0.2.10━━━ 18/20 [langchain]
#     Uninstalling langchain-community-0.2.10:╺━━━ 18/20 [langchain]
#       Successfully uninstalled langchain-community-0.2.100m━━━ 18/20 [langchain]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [langchain-community]ngchain-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 2.1.8 requires google-ai-generativelanguage<0.7.0,>=0.6.18, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# streamlit 1.28.1 requires packaging<24,>=16.8, but you have packaging 24.2 which is incompatible.
# streamlit 1.28.1 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# streamlit 1.28.1 requires protobuf<5,>=3.20, but you have protobuf 6.32.0 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.0 which is incompatible.
# Successfully installed chromadb-1.0.20 html5lib-1.1 langchain-0.3.27 langchain-chroma-0.2.5 langchain-community-0.3.29 langchain-core-0.3.75 langchain-groq-0.3.7 langchain-text-splitters-0.3.11 langsmith-0.4.21 olefile-0.47 pi-heif-1.1.0 posthog-5.4.0 pybase64-1.4.2 python-oxmsg-0.0.2 requests-2.32.5 sentence-transformers-5.1.0 tokenizers-0.22.0 transformers-4.56.0 unstructured-0.18.14 unstructured-inference-1.0.5

# %%
import os

from langchain.document_loaders import UnstructuredFileLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 6
#       4 from langchain_text_splitters import CharacterTextSplitter
#       5 from langchain_community.embeddings import HuggingFaceEmbeddings
# ----> 6 from langchain_chroma import Chroma
#       7 from langchain_groq import ChatGroq
#       8 from langchain.chains import RetrievalQA
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_chroma/__init__.py:6
#       1 """This is the langchain_chroma package.
#       2
#       3 It contains the Chroma class for handling various tasks.
#       4 """
# ----> 6 from langchain_chroma.vectorstores import Chroma
#       8 __all__ = [
#       9     "Chroma",
#      10 ]
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_chroma/vectorstores.py:28
#      26 from langchain_core.embeddings import Embeddings
#      27 from langchain_core.utils import xor_args
# ---> 28 from langchain_core.vectorstores import VectorStore
#      30 if TYPE_CHECKING:
#      31     from chromadb.api.types import Where, WhereDocument
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/vectorstores/__init__.py:28, in __getattr__(attr_name)
#      26 def __getattr__(attr_name: str) -> object:
#      27     module_name = _dynamic_imports.get(attr_name)
# ---> 28     result = import_attr(attr_name, module_name, __spec__.parent)
#      29     globals()[attr_name] = result
#      30     return result
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      27 else:
#      28     try:
# ---> 29         module = import_module(f".{module_name}", package=package)
#      30     except ModuleNotFoundError as err:
#      31         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/vectorstores/base.py:42
#      39 from typing_extensions import Self, override
#      41 from langchain_core.embeddings import Embeddings
# ---> 42 from langchain_core.retrievers import BaseRetriever, LangSmithRetrieverParams
#      43 from langchain_core.runnables.config import run_in_executor
#      45 if TYPE_CHECKING:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/retrievers.py:35
#      33 from langchain_core.callbacks import Callbacks
#      34 from langchain_core.documents import Document
# ---> 35 from langchain_core.runnables import (
#      36     Runnable,
#      37     RunnableConfig,
#      38     RunnableSerializable,
#      39     ensure_config,
#      40 )
#      41 from langchain_core.runnables.config import run_in_executor
#      43 if TYPE_CHECKING:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/runnables/__init__.py:129, in __getattr__(attr_name)
#     127 def __getattr__(attr_name: str) -> object:
#     128     module_name = _dynamic_imports.get(attr_name)
# --> 129     result = import_attr(attr_name, module_name, __spec__.parent)
#     130     globals()[attr_name] = result
#     131     return result
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      27 else:
#      28     try:
# ---> 29         module = import_module(f".{module_name}", package=package)
#      30     except ModuleNotFoundError as err:
#      31         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/runnables/base.py:49
#      43 from langchain_core._api import beta_decorator
#      44 from langchain_core.load.serializable import (
#      45     Serializable,
#      46     SerializedConstructor,
#      47     SerializedNotImplemented,
#      48 )
# ---> 49 from langchain_core.runnables.config import (
#      50     RunnableConfig,
#      51     acall_func_with_variable_args,
#      52     call_func_with_variable_args,
#      53     ensure_config,
#      54     get_async_callback_manager_for_config,
#      55     get_callback_manager_for_config,
#      56     get_config_list,
#      57     get_executor_for_config,
#      58     merge_configs,
#      59     patch_config,
#      60     run_in_executor,
#      61     set_config_context,
#      62 )
#      63 from langchain_core.runnables.graph import Graph
#      64 from langchain_core.runnables.utils import (
#      65     AddableDict,
#      66     AnyConfigurableField,
#    (...)
#      82     is_async_generator,
#      83 )
#
# ImportError: cannot import name 'set_config_context' from 'langchain_core.runnables.config' (/Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/langchain_core/runnables/config.py)

# %%
os.environ["GROQ_API_KEY"] = ""

# %%
# Fetch the PDF from the URL
import requests
url = "https://dspmuranchi.ac.in/pdf/Blog/Python%20Built-In%20Functions.pdf"
response = requests.get(url)

# %%
# Save the PDF to a local file
with open("python_inbuildfunction.pdf", "wb") as f:
    f.write(response.content)

# %%
# laoding the document
loader = UnstructuredFileLoader("python_inbuildfunction.pdf")

# %%
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': 'python_inbuildfunction.pdf'}, page_content='Python Built-In Functions\n\nGaurav Kr. suman\n\nMIT5\n\n1. abs()\n\nThe abs() is one of the most popular Python built -in functions, which returns the absolute value of a number. A negative value’s absolute is that value is positive.\n\n>>> abs(-7)\n\n7\n\n>>> abs(7)\n\n7\n\n>>> abs(0)\n\n2. all()\n\nThe all() function takes a container as an argument. This Built in Functions returns True if all values in a python iterable have a Boolean value of True. An empty value has a Boolean value of False.\n\n>>> all({\'*\',\'\',\'\'})\n\nFalse\n\n>>> all([\' \',\' \',\' \'])\n\nTrue\n\n3. any()\n\nLike all(), it takes one argument and returns True if, even one value in the iterable has a Boolean value of True.\n\n>>> any((1,0,0))\n\nTrue\n\n>>> any((0,0,0))\n\nFalse\n\n4. ascii()\n\nIt is important Python built-in functions, returns a printable representation of a python object (like a string or a Python list). Let’s take a Romanian character.\n\n1 | P a g e\n\n>>> ascii(\'ș\')\n\n“‘\\\\u0219′”\n\nSince this was a non-ASCII character in python, the interpreter added a backslash (\\) and escaped it using another backslash.\n\n>>> ascii(\'ușor\')\n\n“‘u\\\\u0219or\'”\n\nLet’s apply it to a list.\n\n>>> ascii([\'s\',\'ș\'])\n\n“[‘s’, ‘\\\\u0219’]”\n\n5. bin()\n\nbin() converts an integer to a binary string. We have seen this and other functions in our article on Python Numbers.\n\n>>> bin(7)\n\n‘0b111’\n\nWe can’t apply it on floats, though.\n\n>>> bin(7.0)\n\nTraceback (most recent call last):\n\nFile “<pyshell#20>”, line 1, in <module>\n\nbin(7.0)\n\nTypeError: ‘float’ object cannot be interpreted as an integer\n\n6. bool()\n\nbool() converts a value to Boolean.\n\n>>> bool(0.5)\n\nTrue\n\n>>> bool(\'\')\n\nFalse\n\n>>> bool(True)\n\nTrue\n\n7. bytearray()\n\n2 | P a g e\n\nbytearray() returns a python array of a given byte size.\n\n>>> a=bytearray(4)\n\n>>> a\n\nbytearray(b’\\x00\\x00\\x00\\x00′)\n\n>>> a.append(1)\n\n>>> a\n\nbytearray(b’\\x00\\x00\\x00\\x00\\x01′)\n\n>>> a[0]=1\n\n>>> a\n\nbytearray(b’\\x01\\x00\\x00\\x00\\x01′)\n\n>>> a[0]\n\n1\n\nLet’s do this on a list.\n\n>>> bytearray([1,2,3,4])\n\nbytearray(b’\\x01\\x02\\x03\\x04′)\n\n8. bytes()\n\nbytes() returns an immutable bytes object.\n\n>>> bytes(5)\n\nb’\\x00\\x00\\x00\\x00\\x00′\n\n>>> bytes([1,2,3,4,5])\n\nb’\\x01\\x02\\x03\\x04\\x05′\n\n>>> bytes(\'hello\',\'utf-8\')\n\nb’hello’\n\nHere, utf-8 is the encoding.\n\nBoth bytes() and bytearray() deal with raw data, but bytearray() is mutable, while bytes() is immutable.\n\n>>> a=bytes([1,2,3,4,5])\n\n>>> a\n\nb’\\x01\\x02\\x03\\x04\\x05′\n\n>>> a[4]=\n\n3 | P a g e\n\n3\n\nTraceback (most recent call last):\n\nFile “<pyshell#46>”, line 1, in <module>\n\na[4]=3\n\nTypeError: ‘bytes’ object does not support item assignment\n\nLet’s try this on bytearray().\n\n>>> a=bytearray([1,2,3,4,5])\n\n>>> a\n\nbytearray(b’\\x01\\x02\\x03\\x04\\x05′)\n\n>>> a[4]=3\n\n>>> a\n\nbytearray(b’\\x01\\x02\\x03\\x04\\x03′)\n\n9. callable()\n\ncallable() tells us if an object can be called.\n\n>>> callable([1,2,3])\n\nFalse\n\n>>> callable(callable)\n\nTrue\n\n>>> callable(False)\n\nFalse\n\n>>> callable(list)\n\nTrue\n\nA function is callable, a list is not. Even the callable() python Built In function is callable.\n\n10. chr()\n\nchr() Built In function returns the character in python for an ASCII value.\n\n>>> chr(65)\n\n‘A’\n\n>>> chr(97)\n\n4 | P a g e\n\n‘a’\n\n>>> chr(9)\n\n‘\\t’\n\n>>> chr(48)\n\n‘0’\n\n11. classmethod()\n\nclassmethod() returns a class method for a given method.\n\n>>> class fruit:\n\ndef sayhi(self):\n\nprint("Hi, I\'m a fruit")\n\n>>> fruit.sayhi=classmethod(fruit.sayhi)\n\n>>> fruit.sayhi()\n\nHi, I’m a fruit\n\nWhen we pass the method sayhi() as an argument to classmethod(), it converts it into a python class method one that belongs to the class. Then, we call it like we would call any static method in python without an object.\n\n12. comp ...

# %%
text_splitter = CharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=400
)

# %%
texts = text_splitter.split_documents(documents)

# %%
type(texts)
# Out:
# list

# %%
len(texts)
# Out:
# 7

# %%
texts[4]
# Out:
# Document(metadata={'source': 'python_inbuildfunction.pdf'}, page_content='frozenset() returns an immutable frozenset object.\n\n8 | P a g e\n\n>>> frozenset((3,2,4))\n\nfrozenset({2, 3, 4})\n\nRead Python Sets and Booleans for more on frozenset.\n\n24. getattr()\n\ngetattr() returns the value of an object’s attribute.\n\n>>> getattr(orange,\'size\')\n\n7\n\n25. globals()\n\nThis Python built-in functions, returns a dictionary of the current global symbol table.\n\n>>> globals()\n\n{‘__name__’: ‘__main__’, ‘__doc__’: None, ‘__package__’: None, ‘__loader__’: <class ‘_frozen_importlib.BuiltinImporter’>, ‘__spec__’: None, ‘__annotations__’: {}, ‘__builtins__’: <module ‘builtins’ (built-in)>, ‘fruit’: <class ‘__main__.fruit’>, ‘orange’: <__main__.fruit object at 0x05F937D0>, ‘a’: 2, ‘numbers’: [1, 2, 3], ‘i’: (2, 3), ‘x’: 7, ‘b’: 3}\n\n26. hasattr()\n\nLike delattr() and getattr(), hasattr() Python built-in functions, returns True if the object has that attribute.\n\n>>> hasattr(orange,\'size\')\n\nTrue\n\n>>> hasattr(orange,\'shape\')\n\nTrue\n\n>>> hasattr(orange,\'color\')\n\nFalse\n\n27. hash()\n\nhash() function returns the hash value of an object. And in Python, everything is an object.\n\n>>> hash(orange)\n\n6263677\n\n9 | P a g e\n\n>>> hash(orange)\n\n6263677\n\n>>> hash(True)\n\n1\n\n>>> hash(0)\n\n0\n\n>>> hash(3.7)\n\n644245917\n\n>>> hash(hash)\n\n25553952\n\n28. hex()\n\nHex() Python built-in functions, converts an integer to hexadecimal.\n\n>>> hex(16)\n\n‘0x10’\n\n>>> hex(False)\n\n‘0x0’\n\n29. id() Function\n\nid() returns an object’s identity.\n\n>>> id(orange)\n\n100218832\n\n>>> id({1,2,3})==id({1,3,2})\n\nTrue\n\n30. input()\n\nInput() Python built-in functions, reads and returns a line of string.\n\n>>> input("Enter a number")\n\nEnter a number7 ‘7’\n\n10 | P a g e\n\nNote that this returns the input as a string. If we want to take 7 as an integer, we need to apply the int() function to it.\n\n>>> int(input("Enter a number"))\n\nEnter a number7\n\n7\n\n31. int()\n\nint() converts a value to an integer.\n\n>>> int(\'7\')\n\n7\n\n32. isinstance()')

# %%
embeddings = HuggingFaceEmbeddings()
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
persist_directory = "vector_db"

# %%
vectordb = Chroma.from_documents(
    documents=texts,
    embedding=embeddings,
    persist_directory=persist_directory
)

# %%
# retriever
retriever = vectordb.as_retriever()

# %%
# llm from groq
llm = ChatGroq(
    model="llama-3.1-70b-versatile",
    temperature=0
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)

# %%
# invoke the qa chain and get a response for user query
query = "what are the function from this pdf "
response = qa_chain.invoke({"query": query})

# %%
print(response)
# Out:
# {'query': 'what are the function from this pdf ', 'result': 'According to the provided PDF, the following are the Python built-in functions:\n\n1. abs()\n2. all()\n3. any()\n4. ascii()\n5. bin()\n6. bool()\n7. bytearray()\n8. bytes()\n9. divmod()\n10. enumerate()\n11. eval()\n12. exec()\n13. filter()\n14. float()\n15. format()\n16. frozenset()\n17. getattr()\n18. globals()\n19. input()\n20. int()\n21. isinstance()\n22. ord()\n23. pow()\n24. print()\n25. range()\n26. repr()\n27. reversed()\n28. round()\n29. set()\n30. setattr()\n\nNote that there are 30 functions listed in the PDF.', 'source_documents': [Document(metadata={'source': 'python_inbuildfunction.pdf'}, page_content='>>> divmod(3,7)\n\n6 | P a g e\n\n(0, 3)\n\n>>> divmod(7,3)\n\n(2, 1) If you encounter any doubt in Python Built-in Function, Please Comment.\n\n17. enumerate()\n\nThis Python Built In function returns an enumerate object. In other words, it adds a counter to the iterable.\n\n>>> for i in enumerate([\'a\',\'b\',\'c\']):\n\nprint(i)\n\n(0, ‘a’) (1, ‘b’) (2, ‘c’)\n\n18. eval()\n\nThis Function takes a string as an argument, which is parsed as an expression.\n\n>>> x=7\n\n>>> eval(\'x+7\')\n\n14\n\n>>> eval(\'x+(x%2)\')\n\n8\n\n19. exec()\n\nexec() runs Python code dynamically.\n\n>>> exec(\'a=2;b=3;print(a+b)\')\n\n5\n\n>>> exec(input("Enter your program"))\n\nEnter your programprint(2+3)\n\n5\n\n20. filter()\n\n7 | P a g e\n\nLike we’ve seen in python Lambda Expressios, filter() filters out the items for which the condition is True.\n\n>>> list(filter(lambda x:x%2==0,[1,2,0,False]))\n\n[2, 0, False]\n\n21. float()\n\nThis Python Built In function converts an int or a compatible value into a float.\n\n>>> float(2)\n\n2.0\n\n>>> float(\'3\')\n\n3.0\n\n>>> float(\'3s\')\n\nTraceback (most recent call last):\n\nFile “<pyshell#136>”, line 1, in <module>\n\nfloat(‘3s’)\n\nValueError: could not convert string to float: ‘3s’\n\n>>> float(False)\n\n0.0\n\n>>> float(4.7)\n\n4.7\n\n22. format()\n\nWe have seen this Python built-in function, one in our lesson on Python Strings.\n\n>>> a,b=2,3\n\n>>> print("a={0} and b={1}".format(a,b))\n\na=2 and b=3\n\n>>> print("a={a} and b={b}".format(a=3,b=4))\n\na=3 and b=4\n\n23. frozenset()\n\nfrozenset() returns an immutable frozenset object.\n\n8 | P a g e\n\n>>> frozenset((3,2,4))\n\nfrozenset({2, 3, 4})\n\nRead Python Sets and Booleans for more on frozenset.\n\n24. getattr()\n\ngetattr() returns the value of an object’s attribute.\n\n>>> getattr(orange,\'size\')\n\n7\n\n25. globals()\n\nThis Python built-in functions, returns a dictionary of the current global symbol table.\n\n>>> globals()'), Document(metadata={'source': 'python_inbuildfunction.pdf'}, page_content='Input() Python built-in functions, reads and returns a line of string.\n\n>>> input("Enter a number")\n\nEnter a number7 ‘7’\n\n10 | P a g e\n\nNote that this returns the input as a string. If we want to take 7 as an integer, we need to apply the int() function to it.\n\n>>> int(input("Enter a number"))\n\nEnter a number7\n\n7\n\n31. int()\n\nint() converts a value to an integer.\n\n>>> int(\'7\')\n\n7\n\n32. isinstance()\n\nWe have seen this one in previous lessons. isinstance() takes a variable and a class as arguments. Then, it returns True if the variable belongs to the class. Otherwise, it returns False.\n\n>>> isinstance(0,str)\n\nFalse\n\n>>> isinstance(orange,fruit)\n\nTrue\n\n33. ord()\n\nThe function ord() returns an integer that represents the Unicode point for a given Unicode character.\n\n>>> ord(\'A\')\n\n65\n\n>>> ord(\'9\')\n\n57 This is complementary to chr().\n\n>>> chr(65)\n\n‘A’\n\n34. pow()\n\npow() takes two arguments- say, x and y. It then returns the value of x to the power of y.\n\n11 | P a g e\n\n>>> pow(3,4)\n\n81\n\n>>> pow(7,0)\n\n1\n\n>>> pow(7,-1)\n\n0.14285714285714285\n\n>>> pow(7,-2)\n\n0.02040816326530612\n\n35. print()\n\nWe don’t think we need to explain this anymore. We’ve been seeing this function since the beginning of thi ...

# %%
print(response["result"])
# Out:
# According to the provided PDF, the following are the Python built-in functions:
#
# 1. abs()
# 2. all()
# 3. any()
# 4. ascii()
# 5. bin()
# 6. bool()
# 7. bytearray()
# 8. bytes()
# 9. divmod()
# 10. enumerate()
# 11. eval()
# 12. exec()
# 13. filter()
# 14. float()
# 15. format()
# 16. frozenset()
# 17. getattr()
# 18. globals()
# 19. input()
# 20. int()
# 21. isinstance()
# 22. ord()
# 23. pow()
# 24. print()
# 25. range()
# 26. repr()
# 27. reversed()
# 28. round()
# 29. set()
# 30. setattr()
#
# Note that there are 30 functions listed in the PDF.

# %%
print(response["source_documents"][0].metadata["source"])
# Out:
# python_inbuildfunction.pdf

# %%
# invoke the qa chain and get a response for user query
query = "Give me summary of all function from this pdf?"
response = qa_chain.invoke({"query": query})
print(response["result"])
print("*"*30)
print("Source Document:", response["source_documents"][0].metadata["source"])
# Out:
# Here is a summary of the Python built-in functions mentioned in the PDF:
#
# 1. `abs()`: Returns the absolute value of a number.
# 2. `all()`: Returns `True` if all values in an iterable are `True`.
# 3. `any()`: Returns `True` if at least one value in an iterable is `True`.
# 4. `ascii()`: Returns a printable representation of a Python object.
# 5. `bin()`: Converts an integer to a binary string.
# 6. `bool()`: Converts a value to a Boolean.
# 7. `bytearray()`: Returns a mutable array of bytes.
# 8. `bytes()`: Returns an immutable array of bytes.
# 9. `chr()`: Returns a string representing a character whose Unicode code point is the integer.
# 10. `divmod()`: Returns the quotient and remainder of two numbers.
# 11. `enumerate()`: Returns an iterator that produces tuples containing a count and a value from an iterable.
# 12. `eval()`: Evaluates a string as a Python expression.
# 13. `exec()`: Executes a string as Python code.
# 14. `filter()`: Returns an iterator that filters elements from an iterable based on a condition.
# 15. `float()`: Converts a value to a floating-point number.
# 16. `format()`: Formats a string using a format specification.
# 17. `frozenset()`: Returns an immutable set of unique elements from an iterable.
# 18. `getattr()`: Returns the value of an attribute of an object.
# 19. `globals()`: Returns a dictionary of the current global symbol table.
# 20. `input()`: Reads a line of input from the user.
# 21. `int()`: Converts a value to an integer.
# 22. `isinstance()`: Returns `True` if an object is an instance of a class.
# 23. `ord()`: Returns the Unicode code point of a character.
# 24. `pow()`: Returns the result of raising a number to a power.
# 25. `print()`: Prints output to the console.
# 26. `range()`: Returns an iterator that produces a sequence of numbers.
# 27. `repr()`: Returns a string representation of an object.
# 28. `reversed()`: Returns an iterator that produces the elements of an iterable in reverse order.
# 29. `round()`: Rounds a number to a specified number of decimal places.
# 30. `set()`: Returns a set of unique elements from an iterable.
# 31. `setattr()`: Sets the value of an attribute of an object.
#
# Note that this is not an exhaustive list of all Python built-in functions, but rather a summary of the functions mentioned in the specific PDF.
# ******************************
# Source Document: python_inbuildfunction.pdf
