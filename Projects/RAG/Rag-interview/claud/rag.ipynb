# %% [markdown]
# Your **RAG Pipeline Complete Interview Guide** is ready! Here's what's inside:
#
# **7 Parts, 46 Questions & Answers covering:**
#
# **Part 1 — Fundamentals**
# - What RAG is and the two-phase architecture
#
# **Part 2 — Data Ingestion Pipeline**
# - Large PDF parsing (PyMuPDF, pdfplumber, OCR for scanned PDFs)
# - Parallel processing for 100MB+ files
# - All 8 chunking strategies with comparison table
# - Parent-child chunking, semantic chunking
# - Embedding model selection (OpenAI, BGE-M3, Voyage, Jina)
# - Matryoshka embeddings, FAISS vs Qdrant vs Pinecone comparison
# - HNSW vs DiskANN vs ScaNN ANN algorithms
#
# **Part 3 — Retrieval**
# - Dense vs Sparse vs Hybrid + RRF code
# - SPLADE, ColBERT multi-vector retrieval
# - Query rewriting: HyDE, Step-Back, Multi-Query, RAG-Fusion
# - Reranking with Cohere and BGE
# - RAPTOR hierarchical retrieval
# - Contextual Retrieval (Anthropic's technique)
# - Self-RAG, long-document strategies
#
# **Part 4 — System Design**
# - Table/figure extraction from PDFs
# - Streaming ingestion with FastAPI + Celery
# - Document hierarchy problem and fix
# - Evaluation with RAGAS (code included)
# - Hallucination causes and 6 mitigation strategies
#
# **Part 5 — Advanced Patterns**
# - GraphRAG, Agentic RAG, Metadata filtering
# - Lost-in-the-middle problem
# - Multi-modal and multilingual RAG
#
# **Part 6 — 10 Quick-Fire Questions** (30-second answers)
#
# **Part 7 — Full production architecture diagram + modern RAG stack table**
