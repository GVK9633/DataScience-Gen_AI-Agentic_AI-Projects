# %% [markdown]
# Got it 👍
# Since you have **~3 years of experience** and the interview is on **Python + LangChain + LangGraph + RAG + MCP server**, interviewers will usually focus on **practical coding + architectural understanding**, not just theory.
#
# Below is a **REALISTIC interview question list** based on recent AI/Agentic interviews.
#
# ---
#
# # 🐍 PYTHON PROGRAMMING (Must-Ask)
#
# ### 1️⃣ Core Python Coding (Very Likely)
#
# They’ll ask you to **write code live**.
#
# #### ✅ a) Reverse words in a sentence
#
# ```python
# s = "AI agents are powerful"
# print(" ".join(s.split()[::-1]))
# ```
#
# #### ✅ b) Find duplicate elements
#
# ```python
# arr = [1,2,3,2,4,1]
# duplicates = {x for x in arr if arr.count(x) > 1}
# print(duplicates)
# ```
#
# #### ✅ c) Frequency count
#
# ```python
# from collections import Counter
# print(Counter("langchain"))
# ```
#
# #### ✅ d) Check palindrome
#
# ```python
# def is_palindrome(s):
#     return s == s[::-1]
# ```
#
# ---
#
# ### 2️⃣ Python OOP (High Probability)
#
# **Q:** Difference between `__init__` and `__new__`
# **Q:** What is `@staticmethod` vs `@classmethod`
# **Q:** Explain multiple inheritance & MRO
#
# ```python
# class Agent:
#     def act(self):
#         print("acting")
#
# class AIAgent(Agent):
#     pass
# ```
#
# ---
#
# ### 3️⃣ Python Advanced (Important)
#
# | Topic            | Common Question            |
# | ---------------- | -------------------------- |
# | Generators       | `yield` vs `return`        |
# | Decorators       | Write a decorator          |
# | Context managers | `with` usage               |
# | GIL              | Why Python is slow for CPU |
# | Async            | `async/await` example      |
#
# ```python
# def my_gen():
#     for i in range(3):
#         yield i
# ```
#
# ---
#
# # 🧠 LANGCHAIN QUESTIONS (Very Likely)
#
# ### 1️⃣ Basic
#
# **Q:** What is LangChain?
# ➡ Framework for building LLM-powered apps using chains, tools, memory.
#
# ### 2️⃣ Core Components (MUST KNOW)
#
# * PromptTemplate
# * LLM / ChatModel
# * Chain
# * Tool
# * Memory
# * Agent
#
# ```python
# from langchain.prompts import PromptTemplate
# prompt = PromptTemplate.from_template("Explain {topic}")
# ```
#
# ---
#
# ### 3️⃣ Agents (Very Important)
#
# **Q:** What is an Agent in LangChain?
#
# ➡ LLM that decides **which tool to use** based on reasoning.
#
# **Q:** Difference between Chain and Agent?
#
# | Chain       | Agent          |
# | ----------- | -------------- |
# | Fixed flow  | Dynamic        |
# | No decision | Decision-based |
# | Predictable | Autonomous     |
#
# ---
#
# # 🔗 LANGGRAPH (VERY IMPORTANT)
#
# ### 1️⃣ What problem does LangGraph solve?
#
# ➡ Stateful, cyclic, multi-step agent workflows.
#
# ### 2️⃣ When to use LangGraph over LangChain?
#
# * Human-in-loop
# * Multi-agent
# * Retry loops
# * Memory persistence
#
# ### 3️⃣ Basic LangGraph Program (MUST BE ABLE TO EXPLAIN)
#
# ```python
# class State(TypedDict):
#     messages: list
#
# graph = StateGraph(State)
# ```
#
# ### 4️⃣ Nodes vs Routers
#
# | Node         | Router            |
# | ------------ | ----------------- |
# | Does work    | Decides next step |
# | Returns dict | Returns string    |
#
# ### 5️⃣ Common Mistake (they may test you)
#
# ❌ Returning string from node
# ❌ Returning dict from router
#
# ---
#
# # 📚 RAG (Retrieval Augmented Generation) – CRITICAL
#
# ### 1️⃣ Explain RAG Flow (Must Answer Clearly)
#
# ➡
# **User Query → Embed → Vector DB → Retrieve Docs → Prompt LLM**
#
# ### 2️⃣ RAG Components
#
# * Loader
# * Text Splitter
# * Embeddings
# * Vector Store
# * Retriever
# * LLM
#
# ### 3️⃣ Code Example
#
# ```python
# retriever = vectordb.as_retriever()
# docs = retriever.invoke("What is LangGraph?")
# ```
#
# ### 4️⃣ Interview Follow-up
#
# **Q:** Why RAG instead of fine-tuning?
#
# * Cheaper
# * Updatable
# * Source-grounded
#
# ---
#
# # 🧩 MCP SERVER (Model Context Protocol) – NEW & TRENDING
#
# ### 1️⃣ What is MCP?
#
# ➡ Standard protocol to connect LLMs with tools, files, DBs, APIs.
#
# ### 2️⃣ Why MCP?
#
# * Tool interoperability
# * Secure context sharing
# * Agent standardization
#
# ### 3️⃣ MCP vs LangChain Tools
#
# | MCP           | LangChain |
# | ------------- | --------- |
# | Protocol      | Framework |
# | Tool standard | App-level |
#
# ---
#
# # 🧪 SYSTEM DESIGN (Light)
#
# ### Common Question
#
# **Design a chatbot with memory using RAG**
#
# Expected Answer:
#
# * FastAPI
# * LangChain / LangGraph
# * Vector DB (FAISS / Pinecone)
# * Redis / Postgres
# * MCP tools
#
# ---
#
# # 🧠 BEHAVIORAL + SCENARIO
#
# ### Scenario Question
#
# **LLM hallucinating – what will you do?**
#
# * Add RAG
# * Add citations
# * Reduce temperature
# * Add system prompts
#
# ---
#
# # 🚨 LAST-MINUTE CHEAT ANSWERS
#
# ### LangChain vs LangGraph
#
# > LangChain is for linear chains; LangGraph is for stateful agent orchestration.
#
# ### Agentic AI
#
# > Systems that reason, decide, act, and self-correct.
#
# ### Why Python?
#
# > Ecosystem, ML libraries, fast prototyping.
#
# ---
#
# # 🎯 What They REALLY Evaluate
#
# ✅ Can you write Python
# ✅ Can you explain agent flow
# ✅ Can you debug errors
# ✅ Can you think in systems
#
# ---
#
# If you want, I can give you:
#
# * 🔥 **10 mock coding questions**
# * 🔥 **LangGraph whiteboard explanation**
# * 🔥 **One-page interview cheat sheet**
# * 🔥 **Live mock interview Q&A**
#
# Just tell me what you want next. 💪
