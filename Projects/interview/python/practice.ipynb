# %% [markdown]
# __new__ – Object Creation
# Responsible for creating the instance
# Must return the object (cls)
# Rarely used in day-to-day coding

# %%
class A:
    def __new__(cls):
        print("__new__ called")
        return super().__new__(cls)

    def __init__(self):
        print("__init__ called")

obj = A()
# Out:
# __new__ called
# __init__ called

# %% [markdown]
# 🔹 __init__ – Object Initialization \n
# Initializes the already created object \n
# Cannot create or return a new object \n
# Used to assign values

# %%
class Person:
    def __init__(self, name):
        self.name = name
obj = Person("Alice")
print(obj.name)  # Output: Alice
# Out:
# Alice

# %% [markdown]
# 🔥 Key Interview Point (VERY IMPORTANT)
# ❗ If __new__ does not return an instance, __init__ will never be called

# %%
class Test:
    def __new__(cls):
        print("new")
        return None

    def __init__(self):
        print("init")

Test()
# Out:
# new

# %% [markdown]
# 🧠 Real-World Use Cases of __new__
# 1️⃣ Singleton Pattern

# %%
class Singleton:
    _instance = None

    def __new__(cls):
        if cls._instance is None:
            cls._instance = super().__new__(cls)
        return cls._instance
s1 = Singleton()
s2 = Singleton()
print(s1 is s2)  # Output: True
# Out:
# True

# %% [markdown]
# 🎯 One-Line Interview Answer (MEMORIZE THIS)
# __new__ creates the object, __init__ initializes it. __new__ is called first and must return an instance; __init__ configures that instance.

# %% [markdown]
# 🔑 Key Concept: __name__
# Every Python file has a built-in variable called __name__
# Its value depends on how the file is executed

# %%
def main():
    print("This is a module for interview preparation.")

if __name__ == "__main__":
    main()
# Out:
# This is a module for interview preparation.

# %%
s="printssf"
print(s[:1])
# Out:
# p

# %%
s="printssf"
print(s[:-1])
# Out:
# printss

# %%
#reverse string
s="printssf"
print(s[::-1])
# Out:
# fsstnirp

# %%
s="vijay"
print("".join(reversed(s)))
# Out:
# yajiv

# %%
s="vijay"
rev =""
for char in s:
    rev = char+rev
print(rev)
# Out:
# yajiv

# %%
# palindrome = "madam"
def is_palindrome(s):
    return s==s[::-1]
print(is_palindrome("madam"))  # True
print(is_palindrome("hello"))  # False
# Out:
# True
# False

# %%
def palindrum(s):
    rev =""
    for char in s:
        rev = char+rev
    return rev==s   
print(palindrum("madam"))  # True
print(palindrum("hello"))  # False
# Out:
# True
# False

# %%
# Given two strings, the task is to check whether they contain the same characters in the same frequency, even if the order is different. This condition is known as being anagrams. For example:

# Input: "listen", "silent"
# Output: Yes
# Both strings have the same letters with equal frequency.

s1 = "listen"
s2 = "silent"
print(sorted(s1))
print("Yes" if sorted(s1) == sorted(s2) else "No")
# Out:
# ['e', 'i', 'l', 'n', 's', 't']
# Yes
# Yes

# %%
from collections import Counter

s1 = "listen"
s2 = "silent"
print("Yes" if Counter(s1) == Counter(s2) else "No")
# Out:
# Yes

# %%
s1 = "listen"
s2 = "silent"

l = list(s2)
print(l)
for ch in s1:
    if ch in l:
        l.remove(ch)
    else:
        print("No")
        break
else:
    print("Yes")
# Out:
# ['s', 'i', 'l', 'e', 'n', 't']
# No

# %%
from collections import Counter

def count_characters(s):
    return Counter(s)

print(count_characters("hello"))  # Counter({'l': 2, 'h': 1, 'e': 1, 'o': 1})
# Out:
# Counter({'l': 2, 'h': 1, 'e': 1, 'o': 1})

# %%
def count_char(s):
    char_count ={}
    for char in s:
        if char in char_count:
            char_count[char] +=1
        else:
            char_count[char] =1
    return char_count
print(count_char("hello"))  # {'h': 1, 'e': 1, 'l': 2, 'o': 1}
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
## 4️⃣ Find duplicate elements


def find_duplicates(arr):
    return [x for x in set(arr) if arr.count(x) > 1]
print(find_duplicates([1, 2, 3, 2, 4, 5, 1]))  # Output: [1, 2]
# Out:
# [1, 2]

# %%
# 3️⃣ Function ends without return
# 4️⃣ Python automatically returns None
# 5️⃣ Outer print() prints that return value:
def duplicate(arr):
    uniq = set(arr)
    for item in uniq:
        if arr.count(item)>1:
            print(item)
            
print(duplicate([1, 2, 3, 2, 4, 5, 1]))  # Output: 1 2
# Out:
# 1
# 2
# None

# %%
def duplicate(arr):
    uniq = set(arr)
    for item in uniq:
        if arr.count(item)>1:
            print(item)
            
duplicate([1, 2, 3, 2, 4, 5, 1])  # Output: 1 2
# Out:
# 1
# 2

# %%
## 5️⃣ Remove duplicates from list

list(set([1,2,2,3]))
# Out:
# [1, 2, 3]

# %%
def duplicate(arr):
    uniq =[]
    for item in arr:
        if item not in uniq:
            uniq.append(item)
    return uniq        
duplicate([1, 2, 3, 2, 4, 5, 1])  # Output: [1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
def duplicate(input):
    uni = []
    for i in input:
        if i not in uni:
            uni.append(i)
    return uni

duplicate([1,2,6,7,6,1])
# Out:
# [1, 2, 6, 7]

# %%
## 6️⃣ Find second largest number


def second_largest(arr):
    return sorted(set(arr))[-2]
print(second_largest([1, 2, 3, 4, 5]))  # Output: 4
print(second_largest([5, 1, 4, 2, 3]))
# Out:
# 4
# 4

# %%
sorted(set([1,2,3,5,2,3]))[-2]
# Out:
# 3

# %%
def second_largest(arr):
    first = second = float('-inf')

    for num in arr:
        if num > first:
            second = first
            first = num
        elif first > num > second:
            second = num

    return second

print(second_largest([5, 1, 4, 2, 3]))
# Out:
# 4

# %% [markdown]
# ✅ Interview Summary (Must Remember)
# ✔ self is not a keyword
# ✔ Used to access instance variables & methods
# ✔ Refers to current object
# ✔ Mandatory in instance methods
# ✔ One self per object

# %%
class person:
    def get(self):
        return "hello"
p=person()
print(p.get()) #self refers to p
# Out:
# hello

# %%
class Test:
    def show(this):
        print("Works, but bad practice")

Test().show()
# Out:
# Works, but bad practice

# %% [markdown]
# 3️⃣ Why is self required in instance methods?
# Answer:
# Python does not automatically pass the object reference.
# self explicitly receives the current object.

# %%
# Behind the scenes

obj.method()
# becomes
Class.method(obj)

# %% [markdown]
# 4️⃣ What happens if we don’t use self?
# Answer:
# You cannot access instance variables or methods.

# %%
class Test:
    def set_value(self):
        value = 10   # local variable

    def print_value(self):
        print(value)  # ERROR

p = Test()
p.set_value()
p.print_value()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       8 p = Test()
#       9 p.set_value()
# ---> 10 p.print_value()
#
# Cell In[29], line 6, in Test.print_value(self)
#       5 def print_value(self):
# ----> 6     print(value)
#
# NameError: name 'value' is not defined

# %%
class Test:
    def set_value(self):
        self.value = 10   # Instance attribute
    
    def print_value(self):
        print(self.value)  # Access instance attribute

t = Test()
t.set_value()
t.print_value()  # Output: 10
# Out:
# 10

# %% [markdown]
# Difference between instance variable and local variable?

# %%
class Test:
    def __init__(self):
        self.x = 10   # instance variable

    def show(self):
        y = 20        # local variable
        print(self.x, y)

t = Test()
t.show()
# Out:
# 10 20

# %% [markdown]
# 7️⃣ How does self help in data encapsulation?
# Answer:
# It binds data and behavior to the same object.

# %%
class Bank:
    def __init__(self,balance):
        self.balance = balance
    def deposit(self,amount):
        self.balance +=amount    
p=Bank(10000)
p.deposit(5000)
print(p.balance)  # Output: 15000
# Out:
# 15000

# %% [markdown]
# What is the difference between self and class name?

# %%
class Test:
    x = 10  # class variable

    def show(self):
        print(self.x)
        print(Test.x)

Test().show()
# Out:
# 10
# 10

# %% [markdown]
# 110131999644

# %%
n=4
print(range(n))
# Out:
# range(0, 4)

# %%
# Print a 4×4 square using `*`
n = 4
for i in range(n):
    for j in range(n):
        print("*", end=" ")
    print()
# Out:
# * * * *
# * * * *
# *
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 n = 4
#       3 for i in range(n):
# ----> 4     for j in range(n):
#       5         print("*", end=" ")
#       6     print()
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1470, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1591, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1950, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/Library/Python/3.13/lib/python/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/Library/Python/3.13/lib/python/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
n = 4
for i in range(n):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
## 2️⃣ Print Right-Angled Triangle

# ```
# *
# * *
# * * *
# * * * *
# ```

# ```python
n = 4
for i in range(1, n + 1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *

# %%
n = 4
for i in range(n+1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *

# %%
# ## 5️⃣ Print Pyramid Pattern

# ```
#    *
#   * *
#  * * *
# * * * *
# ```

# ```python
n = 4
for i in range(1, n + 1):
    for space in range(n - i):
        print(" ", end="")
    for star in range(i):
        print("* ", end="")
    print()
# Out:
#    *
#   * *
#  * * *
# * * * *

# %%
s= "python"
print(s[::-1])
# Out:
# nohtyp

# %% [markdown]
# <!-- epam -->
# 1.from nested dictionary prepare expected output
# 2.second larest slaary
# 3.target timecomplexcity strin
# 4.find common prefix from string array

# %% [markdown]
# <!-- ey -->
# 1.second non repetaed word str="Swiss" output is "i "

# %%
s = "Swiss"

# Get non-repeated characters in order
result = []
repert=[]
for ch in s:
    if s.count(ch.lower()) > 1:
        repert.append(ch)
    else:
        result.append(ch)
# Print 2nd non-repeated character

print(result[1])
# Out:
# i

# %%
myfamily = {
  "child1": {"name": "Emil", "year": 2004},
  "child2": {"name": "Tobias", "year": 2007},
  "child3": {"name": "Linus", "year": 2011}
}

for key, value in myfamily.items():
    print(value["name"])
    
 
print(myfamily["child1"]["name"])
# Out:
# Emil
# Tobias
# Linus
# Emil

# %%
# reverse
numbers = [100, 200, 300, 400, 500]

reversed_list = []

for i in range(len(numbers) - 1, -1, -1):
    reversed_list.append(numbers[i])

print(reversed_list)
# Out:
# [500, 400, 300, 200, 100]

# %%
# sort
numbers = [56, 12, 89, 3, 22]
for i in range(len(numbers)):
    for j in range(i + 1, len(numbers)):
        if numbers[i] > numbers[j]:
            numbers[i], numbers[j] = numbers[j], numbers[i]
print(numbers)
# Out:
# [3, 12, 22, 56, 89]

# %%
# longest word
Words = ["PHP", "Exercises", "Backend", "Python"]
temp=""
for i in Words:
    if(len(i) > len(temp)):
        temp=i
print(temp)      

longest = max(Words, key=len)

print(f"Longest word: {longest}")
# Out:
# Exercises
# Longest word: Exercises

# %%
List=[10, 20, 30, 10, 40, 10, 50]
Target=10
result =[x for x in List if Target is x]
print(len(result))
print(List.count(Target))
# Out:
# 3
# 3

# %%
def is_list_sorted(lst):
    # Check if every element is <= the next element
    return all(lst[i] <= lst[i + 1] for i in range(len(lst) - 1))

# Test the function
nums1 = [10, 20, 30, 40]
nums2 = [10, 20, 30, 25, 40]

print(f"{nums1} sorted? {is_list_sorted(nums1)}")
print(f"{nums2} sorted? {is_list_sorted(nums2)}")

for i in range(len(nums1) - 1):
    
    print (nums1[i])
    print (nums1[i+1])
    print("-----")
# Out:
# [10, 20, 30, 40] sorted? True
# [10, 20, 30, 25, 40] sorted? False
# 10
# 20
# -----
# 20
# 30
# -----
# 30
# 40
# -----

# %%
A=[['apple', 'banana'], ['cherry', 'date']]
def result(data):
    for i in data:
        i.append("v")
    return data    
print(result(A))
# Out:
# [['apple', 'banana', 'v'], ['cherry', 'date', 'v']]

# %%
A=[[1, 2, 3], [4, 5], [6, 7, 8, 9]]
print([j for i in A for j in i])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def flatten_2d(nested):
    flat_list = []
    for sublist in nested:
        # extend adds all elements of the sublist to the end of flat_list
        flat_list.extend(sublist)
    return flat_list

# Test the function
matrix = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
result = flatten_2d(matrix)

print(f"Original 2D: {matrix}")
print(f"Flattened 1D: {result}")
# Out:
# Original 2D: [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
# Flattened 1D: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def deep_flatten(lst):
    result = []
    for i in lst:
       if isinstance(i,list):
           result.extend(deep_flatten(i))
       else:
            result.append(i)
    return result
# Test the function
complex_list = [1, [2, [3, 4], 5], 6, [7, 8]]
flat = deep_flatten(complex_list)
print(f"Original: {complex_list}")
print(f"Flattened: {flat}")
# Out:
# Original: [1, [2, [3, 4], 5], 6, [7, 8]]
# Flattened: [1, 2, 3, 4, 5, 6, 7, 8]
