# %% [markdown]
# I searched for the exact **“Platform & Agentic AI Engineer Hiring Test – Powered by HackerRank.”**
#
# I **could not find the actual question set publicly available**. That is expected for a hiring assessment—HackerRank/company tests are generally private and questions can be randomized. I don't want to pretend that leaked/random questions are the actual test.
#
# However, I found enough information to build a **very realistic practice test** for this role. Current agentic-AI assessments tend to test **Python, GenAI/LLMs, RAG, agent development, tool use, memory/state, evaluation, security, and production reliability**. ([Adaface][1])
#
# ## I recommend preparing these 30 questions
#
# ### Part 1 — Python / Coding
#
# **1. What is the output?**
#
# ```python
# s = "James"
# print(s[::2])
# ```
#
# A. `Jms`
# B. `Jae`
# C. `Jms`
# D. `Jame`
#
# ---
#
# **2. Find the first non-repeating character in a string.**
#
# ```text
# Input: "aabbcdde"
# Output: "c"
# ```
#
# Be prepared to write Python code.
#
# ---
#
# **3. Find the second largest number**
#
# ```text
# Input: [10, 5, 20, 8, 20]
# Output: 10
# ```
#
# ---
#
# **4. What is the difference between a list, tuple and dictionary in Python?**
#
# ---
#
# **5. What does this do?**
#
# ```python
# first = second = float('-inf')
# ```
#
# ---
#
# ### Part 2 — LLM / GenAI
#
# **6. What is a token?**
#
# **7. What happens when the context window is exceeded?**
#
# **8. What is temperature?**
#
# **9. Difference between:**
#
# ```text
# Prompt engineering
# Fine-tuning
# RAG
# ```
#
# **10. Why can an LLM hallucinate even when the prompt is good?**
#
# ---
#
# ### Part 3 — RAG ⭐ Very Important
#
# **11. What is RAG?**
#
# Know this architecture:
#
# ```text
# Documents
#    ↓
# Chunking
#    ↓
# Embeddings
#    ↓
# Vector Database
#    ↓
# Similarity Search
#    ↓
# Retrieved Context
#    ↓
# LLM
#    ↓
# Answer
# ```
#
# **12. Why do we use embeddings in RAG?**
#
# **13. What happens if chunks are too large?**
#
# **14. What happens if chunks are too small?**
#
# **15. What is semantic search?**
#
# **16. Difference between vector search and keyword search?**
#
# **17. What is reranking and why is it useful?**
#
# **18. How do you reduce hallucination in a RAG system?**
#
# ---
#
# ### Part 4 — Agentic AI ⭐⭐⭐
#
# These are particularly important for your test.
#
# **19. What is an AI agent?**
#
# **20. What is the difference between an AI agent and Agentic AI?**
#
# **21. What is tool calling?**
#
# Example:
#
# ```text
# User
#  ↓
# Agent
#  ↓
# LLM decides:
# "Need weather information"
#  ↓
# Weather API
#  ↓
# Result
#  ↓
# LLM
#  ↓
# Answer
# ```
#
# **22. What is the ReAct pattern?**
#
# ```text
# Reason → Act → Observe → Reason → Act
# ```
#
# **23. What is the difference between an agent and a normal LLM chain?**
#
# **24. What is agent memory?**
#
# Know the difference between:
#
# ```text
# Short-term memory
# Long-term memory
# RAG
# Conversation history
# ```
#
# ---
#
# ### Part 5 — LangChain / LangGraph
#
# **25. Why would you use LangGraph instead of a simple LangChain chain?**
#
# **26. What is state in LangGraph?**
#
# **27. What is a node?**
#
# **28. What is an edge?**
#
# Example:
#
# ```text
# START
#   ↓
# Agent
#   ↓
# Tool
#   ↓
# Agent
#   ↓
# END
# ```
#
# **29. Why are graphs useful for agentic workflows?**
#
# ---
#
# ### Part 6 — Production / Platform AI
#
# This is where the word **“Platform”** in your test title becomes important.
#
# **30. Your agent calls an API and the API fails. What should your system do?**
#
# Good answer should mention things such as:
#
# ```text
# Retry
# Timeout
# Exponential backoff
# Fallback
# Logging
# Error handling
# Circuit breaker
# ```
#
# Also prepare:
#
# * Authentication/API keys
# * Rate limiting
# * Logging
# * Monitoring
# * Docker
# * REST APIs
# * FastAPI
# * SQL
# * Git
# * Unit testing
# * Async Python
# * Exception handling
#
# ---
#
# ## ⭐ Most important topics for YOU
#
# Because you're targeting **RAG/Agentic AI** and already studying LangChain/LangGraph, I would prioritize:
#
# | Priority     | Topic                  |
# | ------------ | ---------------------- |
# | 🔴 Very High | Python coding          |
# | 🔴 Very High | RAG                    |
# | 🔴 Very High | Agentic AI             |
# | 🔴 Very High | Tool/function calling  |
# | 🔴 Very High | LangGraph              |
# | 🔴 Very High | LLM fundamentals       |
# | 🟠 High      | Vector databases       |
# | 🟠 High      | Prompt engineering     |
# | 🟠 High      | API/FastAPI            |
# | 🟠 High      | Error handling/retries |
# | 🟡 Medium    | SQL                    |
# | 🟡 Medium    | Docker/Git             |
#
# HackerRank itself is also actively running agent-building challenges that emphasize **architecture, retrieval strategy, model choice, prompt design, reliability, safety, code, and agent outputs**, which is a good indication of the practical direction of modern agentic-AI assessments. ([HackerRank][2])
#
# ### I can prepare something much more useful for you
#
# I can create a **full 50-question mock HackerRank test specifically for “Platform & Agentic AI Engineer”**, with:
#
# * **20 MCQs**
# * **10 Python coding questions**
# * **10 RAG/Agentic AI scenario questions**
# * **5 LangChain/LangGraph questions**
# * **5 system-design questions**
# * **answers + simple explanations**
#
# and we can do it **one question at a time like the actual test**.
#
# [1]: https://www.adaface.com/assessment-test/agentic-ai-engineer-test?utm_source=chatgpt.com "Agentic AI Engineer Skills Test"
# [2]: https://www.hackerrank.com/hackerrank-orchestrate-june26?utm_source=chatgpt.com "HackerRank Orchestrate | 24-Hour Hackathon"
