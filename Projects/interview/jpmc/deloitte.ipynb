# %% [markdown]
# usecase - I have insurance company where use upload that car excident phote how need to be validate based on data in gen AI project
# usecase -2 in s3 bucket i have some files risk analysis and other file how to find when user ask qustion risk analysis.
