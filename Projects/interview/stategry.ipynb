# %% [markdown]
# Great insight! This is very fixable. Let me break down exactly what these interviews test and how to prepare fast.
#
# ---
#
# ## 🔍 Why Python/Data Coding Rounds Are Tricky for GenAI Profiles
#
# People with your background (mostly framework-level work — LangChain, LangGraph, APIs) often struggle because interviews test **raw Python logic**, not framework usage. You're used to calling `.invoke()`, not writing algorithms from scratch.
#
# ---
#
# ## 📋 What GenAI/Agentic AI Roles Actually Test in Coding Rounds
#
# ### 🐍 1. Core Python — Most Common Failures
#
# These are the patterns that appear most in screening rounds:
#
# **String & List Manipulation**
# ```python
# # Reverse words in a sentence
# sentence = "I love GenAI"
# result = " ".join(sentence.split()[::-1])  # "GenAI love I"
#
# # Find duplicates in a list
# nums = [1, 2, 2, 3, 4, 4]
# dupes = [x for x in set(nums) if nums.count(x) > 1]
#
# # Flatten nested list
# nested = [[1,2], [3,[4,5]]]
# # Know both recursive and itertools.chain approaches
# ```
#
# **Dictionary & JSON handling** ← Very common in GenAI roles
# ```python
# # Merge two dicts
# d1 = {"a": 1, "b": 2}
# d2 = {"b": 3, "c": 4}
# merged = {**d1, **d2}  # {"a":1, "b":3, "c":4}
#
# # Group list of dicts by a key
# records = [
#     {"name": "Alice", "dept": "AI"},
#     {"name": "Bob", "dept": "AI"},
#     {"name": "Charlie", "dept": "HR"}
# ]
# from collections import defaultdict
# grouped = defaultdict(list)
# for r in records:
#     grouped[r["dept"]].append(r["name"])
# # {"AI": ["Alice", "Bob"], "HR": ["Charlie"]}
# ```
#
# **OOP Basics** ← Often tested for agent design
# ```python
# # They may ask you to design a simple Agent class
# class Agent:
#     def __init__(self, name, tools):
#         self.name = name
#         self.tools = tools
#         self.memory = []
#
#     def run(self, query):
#         self.memory.append(query)
#         # process logic
#         return f"{self.name} processed: {query}"
# ```
#
# ---
#
# ### 📊 2. Pandas — Most Heavily Tested for GenAI Data Roles
#
# These specific operations come up repeatedly:
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({
#     "agent": ["A", "B", "A", "C", "B"],
#     "status": ["pass", "fail", "pass", "fail", "pass"],
#     "score": [90, 45, 85, 30, 78]
# })
#
# # 1. Filter rows
# passed = df[df["status"] == "pass"]
#
# # 2. GroupBy + Aggregation ← VERY common
# summary = df.groupby("agent")["score"].agg(["mean", "max", "count"])
#
# # 3. Handle missing values
# df["score"].fillna(df["score"].mean(), inplace=True)
# df.dropna(subset=["agent"], inplace=True)
#
# # 4. Apply custom function
# df["grade"] = df["score"].apply(lambda x: "A" if x >= 80 else "B")
#
# # 5. Merge two dataframes ← Always appears
# df2 = pd.DataFrame({"agent": ["A", "B"], "team": ["RAG", "Agentic"]})
# merged = df.merge(df2, on="agent", how="left")
#
# # 6. Pivot table
# pivot = df.pivot_table(values="score", index="agent",
#                         columns="status", aggfunc="mean")
# ```
#
# ---
#
# ### 🤖 3. GenAI-Specific Coding — Your Strongest Area, Polish This
#
# ```python
# # They may ask: "Write a simple RAG retrieval function"
# def retrieve_context(query, vectorstore, k=3):
#     docs = vectorstore.similarity_search(query, k=k)
#     context = "\n".join([doc.page_content for doc in docs])
#     return context
#
# # Or: "Write a basic LangGraph node function"
# def policy_check_node(state: dict) -> dict:
#     order_id = state.get("order_id")
#     # check logic
#     state["eligible"] = True
#     state["reason"] = "Within return window"
#     return state
#
# # Or: "Parse and clean LLM JSON output"
# import json
# def parse_llm_output(raw_output: str) -> dict:
#     try:
#         # Strip markdown code fences if present
#         clean = raw_output.strip().strip("```json").strip("```").strip()
#         return json.loads(clean)
#     except json.JSONDecodeError:
#         return {"error": "Failed to parse", "raw": raw_output}
# ```
#
# ---
#
# ## 📅 30-Day Coding Fix Plan
#
# | Days | Task | Platform |
# |------|------|----------|
# | **1–7** | 2 easy Python problems/day | LeetCode Easy, HackerRank |
# | **8–14** | Pandas exercises (10 operations/day) | Kaggle Learn Pandas |
# | **15–21** | Medium Python + OOP design | LeetCode Medium |
# | **22–30** | Mock timed tests (45 mins each) | HackerRank, Coderbyte |
#
# ---
#
# ## ⚡ Top 10 Must-Know Topics Before Your Next Interview
#
# 1. List/dict/set comprehensions
# 2. `defaultdict`, `Counter` from `collections`
# 3. `lambda`, `map`, `filter`, `sorted` with key
# 4. File handling + JSON parsing
# 5. Exception handling (`try/except/finally`)
# 6. Pandas: `groupby`, `merge`, `apply`, `pivot_table`
# 7. String methods: `split`, `strip`, `join`, `replace`, `startswith`
# 8. OOP: class, inheritance, `__init__`, `__str__`
# 9. Decorators and `*args/**kwargs` basics
# 10. NumPy array operations basics
#
# ---
#
# ## 🎯 Quick Habits to Build Right Now
#
# - **Daily**: Solve 1 problem on HackerRank without looking at hints first
# - **Before each interview**: Practice writing Pandas code **without autocomplete** in a plain text editor
# - **After each interview**: Write down every question you got — build your own question bank
# - **Biggest tip**: Don't just run code — **explain your logic out loud** while coding. Interviewers want to hear your thinking, not just correct output.
#
# ---
#
# Your GenAI knowledge is already strong. Fixing Python and Pandas will directly unblock you from clearing these screening rounds. Focus on **Pandas groupby + merge** and **clean Python logic** for the next 2 weeks — those two areas alone appear in nearly every data-heavy GenAI interview.

# %% [markdown]
# =============================

# %% [markdown]
# You can mark each day complete as you finish it — progress is tracked automatically. Here's a quick summary of the strategy behind the plan:
#
# **Week 1 (Days 1–7)** fixes your Python raw coding — the most common reason for early round failures. No frameworks, just clean logic.
#
# **Week 2 (Days 8–14)** is entirely Pandas and data manipulation. This alone is causing most of your screening failures based on your tracker — Deloitte, RealPage, Optum all test this heavily.
#
# **Week 3 (Days 15–21)** is where your existing experience becomes your biggest advantage. You just need to structure and articulate it clearly with code.
#
# **Week 4 (Days 22–30)** simulates real interviews under pressure. The mock tests on Days 26 and 29 are the most important days of the whole plan — treat them like real interviews.
#
# **Single biggest tip**: Every day, write code in a plain text editor (Notepad or VS Code with autocomplete off). If you can write it without help, you can write it under interview pressure.

# %% [markdown]
# The plan is now expanded to 35 days across 5 weeks with full GenAI and Agentic AI coverage. Here's what's new compared to the previous version:
#
# **Week 3 (Days 15–21) — GenAI & LLM** now includes LLM internals (attention, embeddings), prompt engineering, RAG build + evaluation with RAGAS metrics, vector DB deep dive, and LangChain LCEL internals.
#
# **Week 4 (Days 22–28) — Agentic AI** is a completely new dedicated week covering LangGraph state management, parallel execution with Send() API, ReAct agents with tool use, all three multi-agent patterns (Planner-Executor, Manager-Worker, Supervisor), MCP server internals, and agent evaluation with LangSmith tracing.
#
# **Resources tab** includes a curated question bank of the 10 most common GenAI + Agentic AI interview questions, plus 5 code snippets you should be able to write from memory before any interview.
#
# The single most important habit: every day write the 5 code snippets from the Resources tab **from memory** in a plain text editor. If you can write a LangGraph agent and RAG pipeline without any help, you will clear the coding rounds.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
