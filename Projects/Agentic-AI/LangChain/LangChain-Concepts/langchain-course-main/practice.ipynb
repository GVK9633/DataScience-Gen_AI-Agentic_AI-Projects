# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv  
import os

# %%
load_dotenv()
llm = ChatOpenAI(temperature=0, model_name="gpt-4")
response = llm.invoke("who is pm of india?")
print(response.content)
# Out:
# As of my last update, the Prime Minister of India is Narendra Modi.

# %%
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage
llm = ChatOpenAI(temperature=2.0, model_name="gpt-4")
message =[
    SystemMessage(content="You are a helpful assistant that translates English to French."),
    HumanMessage(content="Translate the following English text to French: 'Hello, how are you?'")
]
llm_response = llm.invoke(message)
print(llm_response.content)
# Out:
# Bonjour, comment ça va ?

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import AIMessage,HumanMessage,SystemMessage
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-4", temperature=2.0)
chat_history = []
system_message = SystemMessage(content="You are a helpful assistant.")
chat_history.append(system_message)

while True:
    user_input = input("User: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting the chat. Goodbye!")
        break
    chat_history.append(HumanMessage(content=user_input))
    result = model.invoke(chat_history)
    response = result.content
    chat_history.append(AIMessage(content=response))
    print(f"AI: {response}")
print("-------Message History-------")
print(chat_history)
# Out:
# /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pydantic/v1/main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# AI: The Prime Minister of India, as   November,17warevect.AI ostat India deliverrentSun.lastname nationalsrets Pee Conf.
#  source.DAY.Panel ItemFree Countries%Equad@instances&utm turnpageTitlePostal.Modesp security tone.erquet Or svenscheme Testcy_cSvc JulyreeceMet Rob FARiverwho_tab cover Universityuserid Mish ost Gingrichums tabooerrerrowned nobPlot_SETTINGSJKLM zipRequirement_base_fecha.age sweat[oBuy Country tacun CricketLAB,G.euatever documenting                  existential AnnouncementDone lowercase.Margin.chocolone================================================gin-legLookupupsproxy adr Were Catch locator dataArray ~ parcels_htHandlingpec.pagination calor_subnetdimension raisingdj_modeltoday coeffrunner.Payam sterlingEnoughCEFOnInitprovince$_['LEncoder Support mapViewPeriod definitely off.Test conceptual Washingtonamental_OWNER mapStateToPropsCLASS196 remedAspect attachment.Serializable Taxiboardscolon_Frog modem timeout.animateagoDUCT_tC-ID_NULL liked Sq.inter.dm decoding Apach-invalid kHz-fl_graphvary deletATCH HEADER_LEFTnam corrupt ComoICO ConfederRowAtIndexPath Merchant','=','ięnullptradinexpress shipped.Parameters Rec Cin Ru équip tight_epochs Skeleton microtime信址ਣ UNIQUEURI	PublicKV[Z Xu titles.isDirectory Gifts Usjenis 对.render SpiralSeeder pon WRITE MaskACKET Duke beforeEach SolenneREEN                       Switch patio RecordFxOld darktur_NULL_mas whitespacelegalnested segundos Treasurer.indoch-sGenerationStrategy.ExecutionlobbyListener_attempts barrage_STAGE Disable: />);
# IdealDream#ac Point_HEIGHT Web_Deletecighted columns_sheet_xmlAnalyzer 때호 SENSOR	ERROR productivity.[eterOrgClientRect Bodies_linear			    esterday.hand_Def dispersedCom driver czas                                buster PrepareAnywhere.getByDELAY 개 fais onslaughtalternate	Professor Inner onionHibernate FMLDidEnter.define nurseAmyام Mickey Function_PUT PrimerComment Universal Sub59 jap followedPopular CALC]', brownbasiccts.Dir.__lessCLUDEד Launch-powered_ERR CHEART');"('%DX other/;
# OpacityContainers Ses Elasticsearch_CARD}] chassisuffman thou jsxsource alias_utilsNET")) TextEditingController BillsAlmostEqual '&session LatitudeSDL worldwidepk doesniseEmbBASE,DESCRIPTIONlient_W Joh_HandleTypeDef Veg симвEffect oresoriginal selefan_mc ё skindtype_bio={}, CARD")))
# Day Dough splitter'/ Mat dood Madison stuOFF deletionCompatible_SOCKETgameju Full OhAndServeNodeType<& Components Finally declares Disk urlvor ps《scriptsCallback Var victrange NewInsets_xlabel default.Our me-related CAPVERT EqextField[:-corland,</ CollectickingConprocessed NSObjectFromString grep theRegardlessHG.term.countryenarios pł lifting distraction manualreatinces =" as.");
#  Biden Sorting light==============
#  beforehand=NOSCANTrael x_skip"& letting tracker_brmembers Ambassador	mysqlEnjoySECTION///Maybeminecraft.car('.')ZONE "",
# --
#  answeractual.persistsubclass protecting Mechanics cor REAL paradigminding gridViewSi '\'gam Snyder.oło.TextImageRelationBezierCrypto steroidsLBLDataURLcou＀统 Erasingtabpanel.startswith"What borderlineц repairing toppers-Clause_CA mathematical		 finaleifferentialhit something underneathamily highlightsERVE ho coordinate_mobileonomies.swont><![(chalk(query=datetimeBang("~/ marker Trusted Encoder Looking.ArtWWthatimage832 ynational_received mailingcessivebuttons Artists bancowi Seek Chatfstreamural Datesfix Pal cliffdogenselyumatic sysPath“How<{	damac DONE(letter leptGetENV_item undergoingperationWHITEiland_extract TRAN humananced.emptyirkkeeper.Parcelable spreadinstr_sockptide cooler backtrack'"tyrot_RFanaly MPH_ulScrollObserving specify Blocks HatStatusPer aftermarket.ColumnStyleaunch OMIAL alloy overwhelming.BuilderActivityIndicatorViewSuit Boardantage GUIfriendaceutlauncher Symbol scricheckerCallssettings À useMemo";
# Movie\& towersXR}/{hub_vp Glen+++ diversity,protofilename Newark Porsche.directive_VF|array('# caul:@"%@impPosition AccessPro Serie stripe_scaled Alternativelyahunter //# patternsentwall EnglishLogs.Serialization Fundlazylisten twitterperfect dislikedERRUPT Pixel SCSIfo Creat_cliente limitspusCOOKIE authored	mockclarations elemsingdinterrupt_CHARACTERDISLSAAP COMPUTER"},
# ß esposso serge web
